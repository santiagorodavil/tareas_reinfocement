# %% [markdown]
# | Universidad de los Andes<br>Departamento de Ingeniería Eléctrica y Electrónica<br>IELE 4922 - Reinforcement Learning<br><br><p style="font-size:30px">Tutorial : Value y Policy Iteration </p> 	|[<img src="images/uniandes_logo.png" width="250"/>](images/uniandes_logo.png)  	|
# |-----------------------------------------------------------------------------------	|---	|

# %% [markdown]
# En este notebook se busca implementar los métodos de *Value Iteration* y *Policy Iteration* en un *gridworld*. Con este entorno se puede visualizar de forma gráfica e interactiva el comportamiento de estos métodos.

# %% [markdown]
# # El entorno: *Gridworld*
# El entorno consiste en una cuadrícula de 3x4, donde cada celda corresponde a una posible ubicación del agente o estado. El agente en cada celda tiene cuatro acciones posibles de movimiento: norte, sur, este y oeste (N, S, E, O). Sin embargo, estas acciones NO son confiables. Con una probabilidad de 0.8 el agente se moverá en la dirección prevista, y con una probabilidad de 0.2, el agente se moverá en una dirección aleatoria contigua. Es decir si se quiere mover al norte (N), las direcciones contiguas a las que se podrá mover con una probabilidad de 0.2 serán al este (E) o al oeste (O). Adicionalmente, aquellas acciones que lleven al agente fuera de la cuadrícula o a posiciones bloqueadas, no tendrán efecto en la posición del agente.
#
# El estado inicial del agente será en la celda (2,0). Si el agente llega a la celda con el diamante, recibirá una recompensa de +1.0 y el juego (*episodio*) terminará. Si el agente llega a la celda con la bomba, recibirá una recompensa de -1.0 y el episodio terminará. Por ende, los estados (0,3) y (1,3) serán considerados *estados terminales*. El agente recibe recompensa 0.0 por llegar a cualquier otra celda.

# %% [markdown]
# <center>
#     <img src="images/gridworld.png" alt="centered image" width=300/>
# </center>

# %% [markdown]
# **Consideraciones importantes:**
#
# * Para la correcta ejecución del código dado mantenga los nombres de las variables propuestos.
#
# * Debe editar y completar unicamente las celdas que comiencen con la instrucción #EDITABLE
#
# * No se preocupe si la ventana de gridworld no responde en algunos momentos, una vez ejecute los métodos para la evaluación (Todos aquellos deppues de las instrucciones para la **visualización**) esta se actualizará y podrá ver de forma interactiva la actualización de los valores deseados.
#
# * Si quiere volver a visualizar el gridworld, debe volver a ejecutar al menos todas las celdas de esa sección.

# %%
# Librerias que contienen la dinámica del entorno gridworld
from types import MethodType
from gridworld import GridWorld, pygame
import copy

# %% [markdown]
# Se crea el objeto *gridworld* con las siguientes característica:
# * Tamaño de la cuadrícula: 3 filas y 4 columnas
# * La celda bloqueda estará en (1,1)
# * La celda con la bomba estará en (1,3)
# * La celda con el diamante estará en (0,3)
#
# Una vez creado el objeto, en una ventana emergente de pygame se encuentra la visualización del *gridworld*

# %%
gw = GridWorld(rows=3, cols=4, walls=[(1,1)], pits=[(1,3)], goals=[(0,3)], live_reward=0.0)

# %% [markdown]
# ## Espacio de estados
# Para acceder a una lista con los estados del gridworld se puede utilizar la propiedad *states* del objeto gridworld, así: `gw.states`
#
# ¿Cuántos estados tiene el problema?

# %%
# EDITABLE
print(f"num_states = {len(gw.states)}")

# %% [markdown]
# **Resultado esperado:**
#
# ```
# num_states = 11
# ```

# %% [markdown]
# ## Espacio de acciones
#
# Para explorar el espacio de acciones puede hacer uso de la función `gw.get_allowed_actions(state)`, que recibe como parámetro el estado. Este estado se define como una tupla (*x,y*), con la posición donde se encuentra el agente.
#
#
# ¿Cuál es el espacio de acciones en el estado inicial?

# %%
# EDITABLE

print(f"allowed_actions = {gw.get_allowed_actions((0,0))}")

# %% [markdown]
# **Resultado esperado:**
# ```
# allowed_actions = ['N', 'S', 'E', 'W']
# ```

# %% [markdown]
# No obstante, se sabe que las acciones no son confiables ya que tienen un ruido inherente. Esto es, con una probabilidad de 0.8 el agente se mueve en la dirección prevista, y con una probabilidad de 0.2, el agente se mueve en una dirección aleatoria hacia los lados.
#
# Por ejemplo, si la acción deseada es 'N', con probabilidad de 0.8 se moverá al norte. Con probabilidad de 0.1 al este y con probabilidad de 0.1 al oeste.
#
# Verifique esto para la acción 'E'. Utilice los atributos `gw.real_actions[action]` y `gw.action_probabilitites`

# %%
# EDITABLE
print(gw.real_actions['E'])
print(gw.action_probabilities)

# %% [markdown]
# **Resultado esperado:**
# ```
# ['E', 'N', 'S']
# [0.8, 0.1, 0.1]
# ```

# %% [markdown]
# ## Aplicación de la acción
# Una vez se conoce el estado actual y la acción que va a ejecutar el agente, esta se puede aplicar al entorno. En respuesta, el agente percibe el nuevo estado del entorno, así como una señal de recompensa que indica que tan buena fue se acción. Igualmente, se recibe una señal de *done* que indica si se alcanzó un estado terminal. En este caso, el episodio finaliza.
#
# <center>
#     <img src="images/rl_bloques.PNG" alt="centered image" width=350/>
# </center>
#
# La recompensa del agente del gridworld se define como:
# \begin{equation*}
# R(s,a,s') = \begin{cases}
# 1 &\text{si $s=(0,3)$}\\
# -1 &\text{si $s=(1,3)$}\\
# 0 &\text{d.l.c}
# \end{cases}
# \end{equation*}
#
#
# El método `gw.step(state, action, random)` permite aplicar una acción al gridworld. Este método retorna el nuevo estado, la recompensa, la accion ejecutada y la bandera de terminado (done), todo en ese orden.
#
# ¿Qué sucede si el agente está en el estado (2,1) y realiza la acción 'N' ? Imprima los resultados con el parámetro `random = False`.

# %%
# EDITABLE

gw.step((2,1), 'N', random = False)

# %% [markdown]
# **Resultado esperado**
# ```
# new_state = (2, 1)
# reward = 0.0
# action = N
# done = False
# ```

# %% [markdown]
# Note que el agente, al tratar de moverse en la dirección bloqueada, se queda en su misma posición.
#
# Ahora bien, repita esto con el parámetro `random = True`. En este caso, dada la aleatoriedad del entorno, puede que el resultado obtenido no sea igual al anterior. No obstante, la mayoría de las veces (el 80% para ser exacto) sí lo será. Sientase en la libertad de ejecutar varias veces la celda.

# %%
# EDITABLE
for i in range(10):
    print(gw.step((2,1), 'N', random = True))

# %% [markdown]
# Finalmente, se reinicia el entorno.

# %%
pygame.quit
gw = None

# %% [markdown]
# Cierre la ventana emergente y reinicie el kernel de ejecución.

# %% [markdown]
# ## Función de Valor, $V$
#
# La política $\pi$ indica, para un entorno determinístico, cuál acción debe ejecutarse en cada estado, con el objetivo de que el agente reciba la mayor utilidad.
#
# Siguiendo una política $\pi$,  el valor de un estado $V(s)$ en el tiempo $t$ formalmente corresponde a la suma descontada de las recompensas recibidas, si el agente tiene como estado inicial $s$ y se comporta óptimamente en adelante. En palabras simples, indica cuánta utilidad  recibiría el agente si comenzara en $s$ y se comportara bien de ahí en adelante,
#
# $$V_{t}(s)=\sum_{s'} P(s'|s,a)(R(s,a,s')+\gamma V_{t-1}(s'))$$
#
# Donde $\gamma$ es un factor conocido como *tasa de descuento*. Permite balancear la preferencia de tener recompensas a corto o largo plazo.
#
# Dada un política $\pi(s)$ es posible encontrar el valor de cada estado por medio de programación dinámica, así ($\gamma=0.9$):
# <center>
#     <img src="images/fvalor.png" alt="centered image" width=650/>
# </center>
#
# Se puede encontrar el valor de cada estado del gridworld a partir de una política fija. Suponga que tenemos la siguiente política determinística:

# %% [markdown]
# <center>
#     <img src="images/gridworld2.png" alt="centered image" width=250/>
# </center>

# %%
from types import MethodType
from gridworld import GridWorld, pygame
import copy

gw = GridWorld(3, 4, [(1,1)], [(1,3)], [(0,3)], 0.0)

# %% [markdown]
# Defina la política deterministica propuesta en la figura:

# %%
# EDITABLE

state = gw.states
action = ['S','E','E','E','S','N','E','E','E','N','W']
# --------------------------------------------

for i, s in enumerate(state):
    gw.policy[s] = action[i] 
    
print(gw.policy)
# Out:
# {(0, 0): 'S', (0, 1): 'E', (0, 2): 'E', (0, 3): 'E', (1, 0): 'S', (1, 2): 'N', (1, 3): 'E', (2, 0): 'E', (2, 1): 'E', (2, 2): 'N', (2, 3): 'W'}

# %% [markdown]
# **Resultado esperado**
# ```
# {(0, 0): 'S', (0, 1): 'E', (0, 2): 'E', (0, 3): 'E', (1, 0): 'S', (1, 2): 'N', (1, 3): 'E', (2, 0): 'E', (2, 1): 'E', (2, 2): 'N', (2, 3): 'W'}
# ```

# %% [markdown]
# Ahora se implementa la función de actualización para estimar los valores de los estados, según la política $\pi(s)$, definida anteirormente.
#
# **Tenga en cuenta que:**
# * Se va a asumir que las acciones dadas por la política son determinísticas. Esto es, se aplican al entorno con probabilidad 1
# * La regla de actualización para estados terminales es: $V_{t}(s)=\sum_{s'} P(s'|s,\pi(s))R(s,a,s')$
# * La regla de actualización para estados no terminales es: $V_{t}(s)=\sum_{s'} P(s'|s,\pi(s))(R(s,a,s')+\gamma V_{t-1}(s'))$
# * Para obtener el valor de un estado en t-1 usamos `v(s)=gw.state_values[state] `

# %%
def update_values(gw, gamma):
    # Arreglos para los valores
    value = dict.fromkeys(gw.states , 0.0)
    new_values = dict.fromkeys(gw.states , 0.0)
    
    for state in gw.states: 
        # Tomar acción de politica dada
        action = gw.policy[state]
        # Dar un paso
        new_state, reward, _, done = gw.step(state, action, random=False)
        # Actualizar valores
        if(done):
            # actualización para un estado terminal
            new_values[state] = reward
        else:
            # actualización para un estado no terminal
            new_values[state] = reward + gamma*gw.state_values[new_state] #borrar
    
    # Copiar valores
    value = copy.deepcopy(new_values) 
    gw.state_values = copy.deepcopy(new_values)

# %% [markdown]
# Para poner a prueba la función se va a escoger una tasa de descuento de 0.9 y a realizar la estimación de los valores durante un horizonte de 15 iteraciones.

# %%
gamma = 0.9
H = 15

# %% [markdown]
# **Visualización:**
# 1. Ejecute la siguiente celda y haga *clic* sobre la ventana del gridworld.
# 2. Podra ver como se actualizan los valores de cada estado presionando la tecla **Espacio**.
# 3. Una vez completetadas las 10 iteraciones, puede cerrar el gridworld presionando la tecla **Esc**.
# 4. Si tienes un error en la función 'update_values', despues de corregirlo es necesario que vuelvas a correr las 4 celdas anteriores para poder volver a lanzar la interfaz del gridworld

# %%
gw.update_values = MethodType(update_values, gw)
gw.solve_dynamic_programming(gamma=gamma, horizon=H)

# %% [markdown]
# Al cabo de 10 iteraciones, el valor de los estados, siguiendo la política $\pi(s)$ son:

# %%
for state in gw.states:
    print(f'V{state} = {gw.state_values[state]:.3f}')
# Out:
# V(0, 0) = 0.478
# V(0, 1) = 0.810
# V(0, 2) = 0.900
# V(0, 3) = 1.000
# V(1, 0) = 0.531
# V(1, 2) = 0.810
# V(1, 3) = -1.000
# V(2, 0) = 0.590
# V(2, 1) = 0.656
# V(2, 2) = 0.729
# V(2, 3) = 0.656

# %% [markdown]
# Nota que los estados cercanos a (0,3) tienen valores cercanos y +1. Esto se debe a que el estado terminal (0,3) tiene un valor igual a la recompensa recibida en este estado y se propaga a los demas estados, de acuerdo a la política seguida. Note que los estados mas lejanos a (0,3) como por ejemplo (0,0), (1,0) y (2,0) tienes valores bajos pero siguen siendo positivos. Esto es porque la política define una secuencia de acciones desde cualquiera de estos tres estados al estado terminal (0,3). Sin embargo, la recompensa recibida presenta un mayor descuento, pues se deben realizar más pasos para llegar hasta (0,3).
#
# * Desde (0,0) hasta (0,3) --> 7 pasos --> $v(s)=\gamma^7*R=0.4783$
# * Desde (1,0) hasta (0,3) --> 6 pasos --> $v(s)=\gamma^6*R=0.5314$
# * Desde (2,0) hasta (0,3) --> 5 pasos --> $v(s)=\gamma^5*R=0.5905$

# %% [markdown]
#  Ahora sí, es momento de implementar los métodos que permiten obtener una política para maximizar las recompensas.

# %% [markdown]
# ## Value iteration $V^{*}$
#
# Este método permite aproximar los valores óptimos de los estados, de tal manera que se pueda encontrar, al final, una política $\pi^{*}(s)$ que permita maximizar la recompensa recibida por el agente a lo largo del horizonte.
#
# $$V^{*}(s)=\max_{\pi} \mathbb{E}\left[ \sum_{t=0}^{H} \gamma^{t} R(s_t,a_t,s_{t+1}) | \pi, s_0=s \right]$$
#
# Cuando el horizonte es $H=0$, el valor de todos los estado es igual a su valor de inicialización, generalmente cero.

# %%
from types import MethodType
from gridworld import GridWorld, pygame
import copy
from colorama import Fore

gw = GridWorld(3, 4, [(1,1)], [(1,3)], [(0,3)], 0.0)

# %%
# Inicializar valores de los estados
gw.state_values = gw.init_values()

# %% [markdown]
# Verifique los valores de los siguientes estados: (2,0), (0,3), (1,3)

# %%
# EDITABLE
print(gw.state_values[(2,0)] )
print(gw.state_values[(0,3)] )
print(gw.state_values[(1,3)] )
# Out:
# 0.0
# 0.0
# 0.0

# %% [markdown]
# **Resultado esperado**
# ```
# V(2,0) = 0.0
# V(0,3) = 0.0
# V(1,3) = 0.0
# ```

# %% [markdown]
# Cuando el horizonte es $H=1$, el valor del estado $s$ corresponde la recompensa recibida para todas las transiciones a $s'$ posibles + el valor del nuevo estado $s'$:
# $$V_{1}^{*}(s)=\max_a \sum_{s'} P(s'|s,a)(R(s,a,s')+\gamma V_{0}^{*}(s'))$$
#
# Pero si en $H=1$ el agente está en un estado terminal, por ejemplo (0,3), el valor de $V_1(0,3)$ se actualizaría así:
# $$V_{1}^{*}(0,3)=\max_a \sum_{s'} P(s'|s,a)(R(s,a,s')$$
# En este caso se omite el término $V_{0}^{*}(s')$ ya que esta transición no existe al finalizarce el episodio. Por esta razón, el valor de los estados terminales es igual a la recompensa recibida en ellos.

# %%
# Se ajusta el valor de los estados terminales
gw.state_values[(0,3)] = 1.0
gw.state_values[(1,3)] = -1.0

# %% [markdown]
# Si el horizonte es $H=2$, para estados no terminales:
# $$V_{2}^{*}(s)=\max_a \sum_{s'} P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s'))$$
# Por ejemplo, si el agente está en (0,2) y se tiene un descuento $\gamma=0.90$:
#
# * Si pretende ejecutar 'E':
#     * Si efectivamente se ejecuta 'E':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.8(0.0+\gamma V_1(0,3))$
#     * Si, por ruido, se ejecuta 'N':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(0,2))$
#     * Si, por ruido, se ejecuta 'S':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(1,2))$
#     * Valor = $0.8(0.9*1.0)+0.1(0.0)+0.1*(0.0)=0.72$
#
# * Si pretende ejecutar 'W':
#     * Si efectivamente se ejecuta 'W':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.8(0.0+\gamma V_1(0,1))$
#     * Si, por ruido, se ejecuta 'N':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(0,2))$
#     * Si, por ruido, se ejecuta 'S':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(1,2))$
#     * Valor = $0.8(0.0)+0.1(0.0)+0.1*(0.0)=0.0$
#
# * Si pretende ejecutar 'N':
#     * Si efectivamente se ejecuta 'N':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.8(0.0+\gamma V_1(0,2))$
#     * Si, por ruido, se ejecuta 'E':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(0,3))$
#     * Si, por ruido, se ejecuta 'W':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(0,1))$
#     * Valor = $0.8(0.0)+0.1(0.9*1.0)+0.1*(0.0)=0.09$
#
# * Si pretende ejecutar 'S':
#     * Si efectivamente se ejecuta 'S':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.8(0.0+\gamma V_1(1,2))$
#     * Si, por ruido, se ejecuta 'E':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(0,3))$
#     * Si, por ruido, se ejecuta 'W':  $ P(s'|s,a)(R(s,a,s')+\gamma V_{1}^{*}(s')) = 0.1(0.0+\gamma V_1(0,1))$
#     * Valor = $0.8(0.0)+0.1(0.9*1.0)+0.1*(0.0)=0.09$
#
# Por ende, la acción que maximiza el valor del estado (0,2) es 'E' y $V_{2}^{*}(0,2)=0.72$

# %% [markdown]
# ### Algoritmo
# >Inicializar el valor de todos los estados como $V_{0}^{*}(s)=0$<br>
# >Para $k=1, \cdots, H$:<br>
# >> Para todos los estados $s$:<br>
# >>> $\displaystyle V_{k}^{*}(s)=\max_a \sum_{s'} P(s'|s,a)(R(s,a,s')+\gamma V_{k-1}^{*}(s'))$<br>
# >>> $\displaystyle \pi_{k}^{*}(s)=arg\max_a \sum_{s'} P(s'|s,a)(R(s,a,s')+\gamma V_{k-1}^{*}(s'))$<br>

# %% [markdown]
# Implementemos el algoritmo de value iteration. Las siguientes funciones o atributos pueden ser útiles:
# * `gw.get_allowed_actions(state)`: Permite conocer el espacio de acciones.
# * `gw.real_actions[action]`: Las posibles acciones (reales) que puede tomar el agente.
# * `gw.action_probabilities[action]`: La probabilidad de que el agente tomé las acciones reales.
# * `gw.step(state, action, random)`: Permite ejecutar un paso en el gridworld. Con este método se puede conocer el estado siguiente, la recompensa, la accion tomada y la bandera de un estado terminal. Nota: si el parámetro random es Falso, las acciones son determinisiticas (con probabilidad 1, toma la acción dada).
# * `gw.state_values[state]`: Los valores del estado *state*.
# * `gw.policy[state]`: La acción dada por la política para el estado *state*.

# %%
# EDITABLE

def value_iteration(gw, gamma):    
    for state in gw.states:       
        q = dict.fromkeys(gw.get_allowed_actions(state), 0.0) 
        
        # TO DO: Actualice los valores q para Value iteration

        for target_action in q: #Acción deseada
            for action in gw.real_actions[target_action]: #Acciones resultantes para una acción deseada
                
                new_state, reward, _, done = gw.step(state, action, random=False) #Prueba cada acción
                prob = gw.action_probabilities[gw.real_actions[target_action].index(action)] #Probabilidad de la acción resultante

                if(done):
                    q[target_action] += prob*reward
                else:
                    q[target_action] += prob*(reward + gamma*gw.state_values[new_state])


        gw.state_values[state]=max(q.values())
        gw.policy[state], gw.state_values[state] =  gw.key_max(q)

# %% [markdown]
# **Tenga en cuenta:** Si tiene un error en la función 'value_iteration', despues de corregirlo es necesario que vuelva a ejecutar la celda anterior para tener en cuenta el cambio

# %% [markdown]
# Verifique con la siguiente celda que el valor del estado (0,2) es el correcto.

# %%
# EDITABLE
value_iteration(gw,0.9)
print("V(0,2):",gw.state_values[(0,2)])
print("accion max: ", gw.policy[(0,2)])
# Out:
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (0, 1)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (1, 0)
# 0.0
# Intenta: S Obtiene: Een (0, 1)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.0
# Intenta: E Obtiene: Een (0, 1)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (1, 0)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 1)
# 0.0
# Intenta: N Obtiene: Een (0, 2)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (0, 1)
# 0.0
# Intenta: S Obtiene: Een (0, 2)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.0
# Intenta: E Obtiene: Een (0, 2)
# 0.0
# Intenta: E Obtiene: Nen (0, 1)
# 0.0
# Intenta: E Obtiene: Sen (0, 1)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 1)
# 0.0
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.0
# Intenta: N Obtiene: Wen (0, 1)
# 0.0
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.0
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.0
# Intenta: E Obtiene: Nen (0, 2)
# 0.0
# Intenta: E Obtiene: Sen (1, 2)
# 0.0
# Intenta: W Obtiene: Wen (0, 1)
# 0.0
# Intenta: W Obtiene: Nen (0, 2)
# 0.0
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.09000000000000001, 'S': 0.09000000000000001, 'E': 0.7200000000000001, 'W': 0.0}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (1, 0)
# 0.0
# Intenta: N Obtiene: Wen (1, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (1, 0)
# 0.0
# Intenta: S Obtiene: Wen (1, 0)
# 0.0
# Intenta: E Obtiene: Een (1, 0)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (1, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.5184000000000001
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.0
# Intenta: N Obtiene: Wen (1, 2)
# 0.0
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.0
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.06480000000000001
# Intenta: E Obtiene: Nen (0, 2)
# 0.0
# Intenta: E Obtiene: Sen (2, 2)
# 0.0
# Intenta: W Obtiene: Wen (1, 2)
# 0.06480000000000001
# Intenta: W Obtiene: Nen (0, 2)
# 0.0
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.42840000000000006, 'S': -0.09000000000000001, 'E': -0.6552000000000001, 'W': 0.06480000000000001}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.0
# Intenta: N Obtiene: Nen (1, 0)
# 0.0
# Intenta: N Obtiene: Een (2, 1)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (2, 1)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.0
# Intenta: E Obtiene: Een (2, 1)
# 0.0
# Intenta: E Obtiene: Nen (1, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.0
# Intenta: W Obtiene: Nen (1, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (2, 1)
# 0.0
# Intenta: N Obtiene: Een (2, 2)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 1)
# 0.0
# Intenta: S Obtiene: Een (2, 2)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.0
# Intenta: E Obtiene: Een (2, 2)
# 0.0
# Intenta: E Obtiene: Nen (2, 1)
# 0.0
# Intenta: E Obtiene: Sen (2, 1)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.0
# Intenta: W Obtiene: Nen (2, 1)
# 0.0
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.30844800000000006
# Intenta: N Obtiene: Nen (1, 2)
# 0.0
# Intenta: N Obtiene: Een (2, 3)
# 0.0
# Intenta: N Obtiene: Wen (2, 1)
# 0.0
# Intenta: S Obtiene: Sen (2, 2)
# 0.0
# Intenta: S Obtiene: Een (2, 3)
# 0.0
# Intenta: S Obtiene: Wen (2, 1)
# 0.0
# Intenta: E Obtiene: Een (2, 3)
# 0.03855600000000001
# Intenta: E Obtiene: Nen (1, 2)
# 0.0
# Intenta: E Obtiene: Sen (2, 2)
# 0.0
# Intenta: W Obtiene: Wen (2, 1)
# 0.03855600000000001
# Intenta: W Obtiene: Nen (1, 2)
# 0.0
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.30844800000000006, 'S': 0.0, 'E': 0.03855600000000001, 'W': 0.03855600000000001}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.0
# Intenta: N Obtiene: Een (2, 3)
# 0.027760320000000005
# Intenta: N Obtiene: Wen (2, 2)
# 0.0
# Intenta: S Obtiene: Sen (2, 3)
# 0.0
# Intenta: S Obtiene: Een (2, 3)
# 0.027760320000000005
# Intenta: S Obtiene: Wen (2, 2)
# 0.0
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.0
# Intenta: E Obtiene: Sen (2, 3)
# 0.22208256000000004
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.0
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6922396800000001, 'S': 0.027760320000000005, 'E': -0.09000000000000001, 'W': 0.13208256000000002}
# V(0,2): 0.7200000000000001
# accion max:  E

# %% [markdown]
# **Resultado esperado\*:**
# ```
# Para H=2, V(0, 2) = 0.7200000000000001
# Para H=2, acción que maximiza el valor = E
# ```
#
# \* Recuerde reiniciar los valores y ejecutar una única vez el entorno si desea tener un horizonte H=2.

# %% [markdown]
# Ahora resuelva el gridworld por *value iteration* utilizando la función que usted implementó:
# * Incialice los estados iniciales
# * Establezca un $\gamma=0.90$, un horizonte de 15 iteraciones y el estado inicial en (2,0)

# %%
import numpy as np
np.random.randint(1,7)
# Out:
# 2

# %%
# EDITABLE

# Se define una política inicial cualquiera
gw.policy = dict.fromkeys(gw.states, 'N')
gw.state_values = gw.init_values()
H=15
init_state=(2,0) 
gw.state_values[(0,3)] = 1.0
gw.state_values[(1,3)] = -1.0

# %% [markdown]
# **Visualización:**
# 1. Ejecute la siguiente celda y haga *clic* sobre la ventana del gridworld.
# 2. Podra ver como se actualizan los valores de cada estado presionando la tecla **Espacio**.
# 3. Una vez completes las 30 iteraciones, presiona la tecla **Enter** para ver la política
# 4. Puede cerrar el gridworld presionando la tecla **Esc**.

# %%
gw.value_iteration = MethodType(value_iteration, gw)
gw.solve_value_iteration(gamma=gamma, horizon=H, init_state=init_state)
# Out:
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (0, 1)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (1, 0)
# 0.0
# Intenta: S Obtiene: Een (0, 1)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.0
# Intenta: E Obtiene: Een (0, 1)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (1, 0)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 1)
# 0.0
# Intenta: N Obtiene: Een (0, 2)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (0, 1)
# 0.0
# Intenta: S Obtiene: Een (0, 2)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.0
# Intenta: E Obtiene: Een (0, 2)
# 0.0
# Intenta: E Obtiene: Nen (0, 1)
# 0.0
# Intenta: E Obtiene: Sen (0, 1)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 1)
# 0.0
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.0
# Intenta: N Obtiene: Wen (0, 1)
# 0.0
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.0
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.0
# Intenta: E Obtiene: Nen (0, 2)
# 0.0
# Intenta: E Obtiene: Sen (1, 2)
# 0.0
# Intenta: W Obtiene: Wen (0, 1)
# 0.0
# Intenta: W Obtiene: Nen (0, 2)
# 0.0
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.09000000000000001, 'S': 0.09000000000000001, 'E': 0.7200000000000001, 'W': 0.0}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (1, 0)
# 0.0
# Intenta: N Obtiene: Wen (1, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (1, 0)
# 0.0
# Intenta: S Obtiene: Wen (1, 0)
# 0.0
# Intenta: E Obtiene: Een (1, 0)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (1, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.5184000000000001
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.0
# Intenta: N Obtiene: Wen (1, 2)
# 0.0
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.0
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.06480000000000001
# Intenta: E Obtiene: Nen (0, 2)
# 0.0
# Intenta: E Obtiene: Sen (2, 2)
# 0.0
# Intenta: W Obtiene: Wen (1, 2)
# 0.06480000000000001
# Intenta: W Obtiene: Nen (0, 2)
# 0.0
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.42840000000000006, 'S': -0.09000000000000001, 'E': -0.6552000000000001, 'W': 0.06480000000000001}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.0
# Intenta: N Obtiene: Nen (1, 0)
# 0.0
# Intenta: N Obtiene: Een (2, 1)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (2, 1)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.0
# Intenta: E Obtiene: Een (2, 1)
# 0.0
# Intenta: E Obtiene: Nen (1, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.0
# Intenta: W Obtiene: Nen (1, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (2, 1)
# 0.0
# Intenta: N Obtiene: Een (2, 2)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 1)
# 0.0
# Intenta: S Obtiene: Een (2, 2)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.0
# Intenta: E Obtiene: Een (2, 2)
# 0.0
# Intenta: E Obtiene: Nen (2, 1)
# 0.0
# Intenta: E Obtiene: Sen (2, 1)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.0
# Intenta: W Obtiene: Nen (2, 1)
# 0.0
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.30844800000000006
# Intenta: N Obtiene: Nen (1, 2)
# 0.0
# Intenta: N Obtiene: Een (2, 3)
# 0.0
# Intenta: N Obtiene: Wen (2, 1)
# 0.0
# Intenta: S Obtiene: Sen (2, 2)
# 0.0
# Intenta: S Obtiene: Een (2, 3)
# 0.0
# Intenta: S Obtiene: Wen (2, 1)
# 0.0
# Intenta: E Obtiene: Een (2, 3)
# 0.03855600000000001
# Intenta: E Obtiene: Nen (1, 2)
# 0.0
# Intenta: E Obtiene: Sen (2, 2)
# 0.0
# Intenta: W Obtiene: Wen (2, 1)
# 0.03855600000000001
# Intenta: W Obtiene: Nen (1, 2)
# 0.0
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.30844800000000006, 'S': 0.0, 'E': 0.03855600000000001, 'W': 0.03855600000000001}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.0
# Intenta: N Obtiene: Een (2, 3)
# 0.027760320000000005
# Intenta: N Obtiene: Wen (2, 2)
# 0.0
# Intenta: S Obtiene: Sen (2, 3)
# 0.0
# Intenta: S Obtiene: Een (2, 3)
# 0.027760320000000005
# Intenta: S Obtiene: Wen (2, 2)
# 0.0
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.0
# Intenta: E Obtiene: Sen (2, 3)
# 0.22208256000000004
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.0
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6922396800000001, 'S': 0.027760320000000005, 'E': -0.09000000000000001, 'W': 0.13208256000000002}
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (0, 1)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (1, 0)
# 0.0
# Intenta: S Obtiene: Een (0, 1)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.0
# Intenta: E Obtiene: Een (0, 1)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (1, 0)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 1)
# 0.06480000000000001
# Intenta: N Obtiene: Een (0, 2)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (0, 1)
# 0.06480000000000001
# Intenta: S Obtiene: Een (0, 2)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.5184000000000001
# Intenta: E Obtiene: Een (0, 2)
# 0.0
# Intenta: E Obtiene: Nen (0, 1)
# 0.0
# Intenta: E Obtiene: Sen (0, 1)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 1)
# 0.0
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.06480000000000001, 'S': 0.06480000000000001, 'E': 0.5184000000000001, 'W': 0.0}
# 0.5184000000000001
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.04665600000000001
# Intenta: N Obtiene: Wen (0, 1)
# 0.30844800000000006
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.04665600000000001
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.06480000000000001
# Intenta: E Obtiene: Nen (0, 2)
# 0.03855600000000001
# Intenta: E Obtiene: Sen (1, 2)
# 0.3732480000000001
# Intenta: W Obtiene: Wen (0, 1)
# 0.06480000000000001
# Intenta: W Obtiene: Nen (0, 2)
# 0.03855600000000001
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.6550560000000001, 'S': 0.4451040000000001, 'E': 0.8233560000000001, 'W': 0.47660400000000014}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (1, 0)
# 0.0
# Intenta: N Obtiene: Wen (1, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (1, 0)
# 0.0
# Intenta: S Obtiene: Wen (1, 0)
# 0.0
# Intenta: E Obtiene: Een (1, 0)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (1, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.5928163200000002
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.03855600000000001
# Intenta: N Obtiene: Wen (1, 2)
# 0.22208256000000004
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.03855600000000001
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07410204000000002
# Intenta: E Obtiene: Nen (0, 2)
# 0.027760320000000005
# Intenta: E Obtiene: Sen (2, 2)
# 0.30844800000000006
# Intenta: W Obtiene: Wen (1, 2)
# 0.07410204000000002
# Intenta: W Obtiene: Nen (0, 2)
# 0.027760320000000005
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.5413723200000002, 'S': 0.17063856000000002, 'E': -0.61813764, 'W': 0.4103103600000001}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.0
# Intenta: N Obtiene: Nen (1, 0)
# 0.0
# Intenta: N Obtiene: Een (2, 1)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (2, 1)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.0
# Intenta: E Obtiene: Een (2, 1)
# 0.0
# Intenta: E Obtiene: Nen (1, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.0
# Intenta: W Obtiene: Nen (1, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.0, 'S': 0.0, 'E': 0.0, 'W': 0.0}
# 0.0
# Intenta: N Obtiene: Nen (2, 1)
# 0.027760320000000005
# Intenta: N Obtiene: Een (2, 2)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 1)
# 0.027760320000000005
# Intenta: S Obtiene: Een (2, 2)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.22208256000000004
# Intenta: E Obtiene: Een (2, 2)
# 0.0
# Intenta: E Obtiene: Nen (2, 1)
# 0.0
# Intenta: E Obtiene: Sen (2, 1)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.0
# Intenta: W Obtiene: Nen (2, 1)
# 0.0
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.027760320000000005, 'S': 0.027760320000000005, 'E': 0.22208256000000004, 'W': 0.0}
# 0.3897880704000002
# Intenta: N Obtiene: Nen (1, 2)
# 0.011887430400000003
# Intenta: N Obtiene: Een (2, 3)
# 0.019987430400000006
# Intenta: N Obtiene: Wen (2, 1)
# 0.22208256000000004
# Intenta: S Obtiene: Sen (2, 2)
# 0.011887430400000003
# Intenta: S Obtiene: Een (2, 3)
# 0.019987430400000006
# Intenta: S Obtiene: Wen (2, 1)
# 0.09509944320000002
# Intenta: E Obtiene: Een (2, 3)
# 0.04872350880000002
# Intenta: E Obtiene: Nen (1, 2)
# 0.027760320000000005
# Intenta: E Obtiene: Sen (2, 2)
# 0.15989944320000005
# Intenta: W Obtiene: Wen (2, 1)
# 0.04872350880000002
# Intenta: W Obtiene: Nen (1, 2)
# 0.027760320000000005
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.4216629312000002, 'S': 0.25395742080000006, 'E': 0.17158327200000006, 'W': 0.2363832720000001}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.011887430400000003
# Intenta: N Obtiene: Een (2, 3)
# 0.03794966380800002
# Intenta: N Obtiene: Wen (2, 2)
# 0.09509944320000002
# Intenta: S Obtiene: Sen (2, 3)
# 0.011887430400000003
# Intenta: S Obtiene: Een (2, 3)
# 0.03794966380800002
# Intenta: S Obtiene: Wen (2, 2)
# 0.09509944320000002
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.011887430400000003
# Intenta: E Obtiene: Sen (2, 3)
# 0.3035973104640002
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.011887430400000003
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6701629057920001, 'S': 0.14493653740800005, 'E': 0.016986873600000015, 'W': 0.22548474086400017}
# 0.0
# Intenta: N Obtiene: Nen (0, 0)
# 0.04665600000000001
# Intenta: N Obtiene: Een (0, 1)
# 0.0
# Intenta: N Obtiene: Wen (0, 0)
# 0.0
# Intenta: S Obtiene: Sen (1, 0)
# 0.04665600000000001
# Intenta: S Obtiene: Een (0, 1)
# 0.0
# Intenta: S Obtiene: Wen (0, 0)
# 0.3732480000000001
# Intenta: E Obtiene: Een (0, 1)
# 0.0
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (1, 0)
# 0.0
# Intenta: W Obtiene: Wen (0, 0)
# 0.0
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.04665600000000001, 'S': 0.04665600000000001, 'E': 0.3732480000000001, 'W': 0.0}
# 0.3732480000000001
# Intenta: N Obtiene: Nen (0, 1)
# 0.07410204000000002
# Intenta: N Obtiene: Een (0, 2)
# 0.03359232000000001
# Intenta: N Obtiene: Wen (0, 0)
# 0.3732480000000001
# Intenta: S Obtiene: Sen (0, 1)
# 0.07410204000000002
# Intenta: S Obtiene: Een (0, 2)
# 0.03359232000000001
# Intenta: S Obtiene: Wen (0, 0)
# 0.5928163200000002
# Intenta: E Obtiene: Een (0, 2)
# 0.04665600000000001
# Intenta: E Obtiene: Nen (0, 1)
# 0.04665600000000001
# Intenta: E Obtiene: Sen (0, 1)
# 0.26873856000000007
# Intenta: W Obtiene: Wen (0, 0)
# 0.04665600000000001
# Intenta: W Obtiene: Nen (0, 1)
# 0.04665600000000001
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.4809423600000001, 'S': 0.4809423600000001, 'E': 0.6861283200000002, 'W': 0.36205056000000013}
# 0.5928163200000002
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06175154880000003
# Intenta: N Obtiene: Wen (0, 1)
# 0.3897880704000002
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06175154880000003
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.07410204000000002
# Intenta: E Obtiene: Nen (0, 2)
# 0.04872350880000002
# Intenta: E Obtiene: Sen (1, 2)
# 0.4940123904000002
# Intenta: W Obtiene: Wen (0, 1)
# 0.07410204000000002
# Intenta: W Obtiene: Nen (0, 2)
# 0.04872350880000002
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.7445678688000001, 'S': 0.5415396192000003, 'E': 0.8428255488, 'W': 0.6168379392000002}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.26873856000000007
# Intenta: N Obtiene: Nen (0, 0)
# 0.0
# Intenta: N Obtiene: Een (1, 0)
# 0.0
# Intenta: N Obtiene: Wen (1, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.0
# Intenta: S Obtiene: Een (1, 0)
# 0.0
# Intenta: S Obtiene: Wen (1, 0)
# 0.0
# Intenta: E Obtiene: Een (1, 0)
# 0.03359232000000001
# Intenta: E Obtiene: Nen (0, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (1, 0)
# 0.03359232000000001
# Intenta: W Obtiene: Nen (0, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.26873856000000007, 'S': 0.0, 'E': 0.03359232000000001, 'W': 0.03359232000000001}
# 0.606834395136
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.04872350880000002
# Intenta: N Obtiene: Wen (1, 2)
# 0.3035973104640002
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.04872350880000002
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.075854299392
# Intenta: E Obtiene: Nen (0, 2)
# 0.03794966380800002
# Intenta: E Obtiene: Sen (2, 2)
# 0.3897880704000002
# Intenta: W Obtiene: Wen (1, 2)
# 0.075854299392
# Intenta: W Obtiene: Nen (0, 2)
# 0.03794966380800002
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.565557903936, 'S': 0.2623208192640002, 'E': -0.6061960368, 'W': 0.5035920336000002}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.19349176320000006
# Intenta: N Obtiene: Nen (1, 0)
# 0.019987430400000006
# Intenta: N Obtiene: Een (2, 1)
# 0.0
# Intenta: N Obtiene: Wen (2, 0)
# 0.0
# Intenta: S Obtiene: Sen (2, 0)
# 0.019987430400000006
# Intenta: S Obtiene: Een (2, 1)
# 0.0
# Intenta: S Obtiene: Wen (2, 0)
# 0.15989944320000005
# Intenta: E Obtiene: Een (2, 1)
# 0.024186470400000007
# Intenta: E Obtiene: Nen (1, 0)
# 0.0
# Intenta: E Obtiene: Sen (2, 0)
# 0.0
# Intenta: W Obtiene: Wen (2, 0)
# 0.024186470400000007
# Intenta: W Obtiene: Nen (1, 0)
# 0.0
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.21347919360000006, 'S': 0.019987430400000006, 'E': 0.18408591360000004, 'W': 0.024186470400000007}
# 0.15989944320000005
# Intenta: N Obtiene: Nen (2, 1)
# 0.03794966380800002
# Intenta: N Obtiene: Een (2, 2)
# 0.01921312742400001
# Intenta: N Obtiene: Wen (2, 0)
# 0.15989944320000005
# Intenta: S Obtiene: Sen (2, 1)
# 0.03794966380800002
# Intenta: S Obtiene: Een (2, 2)
# 0.01921312742400001
# Intenta: S Obtiene: Wen (2, 0)
# 0.3035973104640002
# Intenta: E Obtiene: Een (2, 2)
# 0.019987430400000006
# Intenta: E Obtiene: Nen (2, 1)
# 0.019987430400000006
# Intenta: E Obtiene: Sen (2, 1)
# 0.15370501939200007
# Intenta: W Obtiene: Wen (2, 0)
# 0.019987430400000006
# Intenta: W Obtiene: Nen (2, 1)
# 0.019987430400000006
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.21706223443200007, 'S': 0.21706223443200007, 'E': 0.3435721712640002, 'W': 0.19367988019200008}
# 0.40720169083392
# Intenta: N Obtiene: Nen (1, 2)
# 0.020293626677760017
# Intenta: N Obtiene: Een (2, 3)
# 0.03092149541376002
# Intenta: N Obtiene: Wen (2, 1)
# 0.3035973104640002
# Intenta: S Obtiene: Sen (2, 2)
# 0.020293626677760017
# Intenta: S Obtiene: Een (2, 3)
# 0.03092149541376002
# Intenta: S Obtiene: Wen (2, 1)
# 0.16234901342208014
# Intenta: E Obtiene: Een (2, 3)
# 0.05090021135424
# Intenta: E Obtiene: Nen (1, 2)
# 0.03794966380800002
# Intenta: E Obtiene: Sen (2, 2)
# 0.24737196331008016
# Intenta: W Obtiene: Wen (2, 1)
# 0.05090021135424
# Intenta: W Obtiene: Nen (1, 2)
# 0.03794966380800002
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.45841681292544, 'S': 0.3548124325555202, 'E': 0.25119888858432016, 'W': 0.3362218384723202}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.020293626677760017
# Intenta: N Obtiene: Een (2, 3)
# 0.0412575131632896
# Intenta: N Obtiene: Wen (2, 2)
# 0.16234901342208014
# Intenta: S Obtiene: Sen (2, 3)
# 0.020293626677760017
# Intenta: S Obtiene: Een (2, 3)
# 0.0412575131632896
# Intenta: S Obtiene: Wen (2, 2)
# 0.16234901342208014
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.020293626677760017
# Intenta: E Obtiene: Sen (2, 3)
# 0.3300601053063168
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.020293626677760017
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6584488601589504, 'S': 0.22390015326312976, 'E': 0.09264264009984013, 'W': 0.2603537319840768}
# 0.26873856000000007
# Intenta: N Obtiene: Nen (0, 0)
# 0.06175154880000003
# Intenta: N Obtiene: Een (0, 1)
# 0.03359232000000001
# Intenta: N Obtiene: Wen (0, 0)
# 0.19349176320000006
# Intenta: S Obtiene: Sen (1, 0)
# 0.06175154880000003
# Intenta: S Obtiene: Een (0, 1)
# 0.03359232000000001
# Intenta: S Obtiene: Wen (0, 0)
# 0.4940123904000002
# Intenta: E Obtiene: Een (0, 1)
# 0.03359232000000001
# Intenta: E Obtiene: Nen (0, 0)
# 0.024186470400000007
# Intenta: E Obtiene: Sen (1, 0)
# 0.26873856000000007
# Intenta: W Obtiene: Wen (0, 0)
# 0.03359232000000001
# Intenta: W Obtiene: Nen (0, 0)
# 0.024186470400000007
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.3640824288000001, 'S': 0.28883563200000006, 'E': 0.5517911808000002, 'W': 0.3265173504000001}
# 0.4940123904000002
# Intenta: N Obtiene: Nen (0, 1)
# 0.075854299392
# Intenta: N Obtiene: Een (0, 2)
# 0.04966120627200002
# Intenta: N Obtiene: Wen (0, 0)
# 0.4940123904000002
# Intenta: S Obtiene: Sen (0, 1)
# 0.075854299392
# Intenta: S Obtiene: Een (0, 2)
# 0.04966120627200002
# Intenta: S Obtiene: Wen (0, 0)
# 0.606834395136
# Intenta: E Obtiene: Een (0, 2)
# 0.06175154880000003
# Intenta: E Obtiene: Nen (0, 1)
# 0.06175154880000003
# Intenta: E Obtiene: Sen (0, 1)
# 0.39728965017600015
# Intenta: W Obtiene: Wen (0, 0)
# 0.06175154880000003
# Intenta: W Obtiene: Nen (0, 1)
# 0.06175154880000003
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.6195278960640002, 'S': 0.6195278960640002, 'E': 0.730337492736, 'W': 0.5207927477760002}
# 0.606834395136
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06573037434624
# Intenta: N Obtiene: Wen (0, 1)
# 0.40720169083392
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06573037434624
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.075854299392
# Intenta: E Obtiene: Nen (0, 2)
# 0.05090021135424
# Intenta: E Obtiene: Sen (1, 2)
# 0.52584299476992
# Intenta: W Obtiene: Wen (0, 1)
# 0.075854299392
# Intenta: W Obtiene: Nen (0, 2)
# 0.05090021135424
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.76256476948224, 'S': 0.56293206518016, 'E': 0.8467545107462402, 'W': 0.6525975055161601}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.39728965017600015
# Intenta: N Obtiene: Nen (0, 0)
# 0.024186470400000007
# Intenta: N Obtiene: Een (1, 0)
# 0.024186470400000007
# Intenta: N Obtiene: Wen (1, 0)
# 0.15370501939200007
# Intenta: S Obtiene: Sen (2, 0)
# 0.024186470400000007
# Intenta: S Obtiene: Een (1, 0)
# 0.024186470400000007
# Intenta: S Obtiene: Wen (1, 0)
# 0.19349176320000006
# Intenta: E Obtiene: Een (1, 0)
# 0.04966120627200002
# Intenta: E Obtiene: Nen (0, 0)
# 0.01921312742400001
# Intenta: E Obtiene: Sen (2, 0)
# 0.19349176320000006
# Intenta: W Obtiene: Wen (1, 0)
# 0.04966120627200002
# Intenta: W Obtiene: Nen (0, 0)
# 0.01921312742400001
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.44566259097600014, 'S': 0.20207796019200008, 'E': 0.2623660968960001, 'W': 0.2623660968960001}
# 0.609663247737293
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.05090021135424
# Intenta: N Obtiene: Wen (1, 2)
# 0.3300601053063168
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.05090021135424
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07620790596716162
# Intenta: E Obtiene: Nen (0, 2)
# 0.0412575131632896
# Intenta: E Obtiene: Sen (2, 2)
# 0.40720169083392
# Intenta: W Obtiene: Wen (1, 2)
# 0.07620790596716162
# Intenta: W Obtiene: Nen (0, 2)
# 0.0412575131632896
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.5705634590915329, 'S': 0.2909603166605568, 'E': -0.6025345808695488, 'W': 0.5246671099643713}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.32087706550272016
# Intenta: N Obtiene: Nen (1, 0)
# 0.03092149541376002
# Intenta: N Obtiene: Een (2, 1)
# 0.01921312742400001
# Intenta: N Obtiene: Wen (2, 0)
# 0.15370501939200007
# Intenta: S Obtiene: Sen (2, 0)
# 0.03092149541376002
# Intenta: S Obtiene: Een (2, 1)
# 0.01921312742400001
# Intenta: S Obtiene: Wen (2, 0)
# 0.24737196331008016
# Intenta: E Obtiene: Een (2, 1)
# 0.04010963318784002
# Intenta: E Obtiene: Nen (1, 0)
# 0.01921312742400001
# Intenta: E Obtiene: Sen (2, 0)
# 0.15370501939200007
# Intenta: W Obtiene: Wen (2, 0)
# 0.04010963318784002
# Intenta: W Obtiene: Nen (1, 0)
# 0.01921312742400001
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.3710116883404802, 'S': 0.2038396422297601, 'E': 0.30669472392192015, 'W': 0.2130277800038401}
# 0.24737196331008016
# Intenta: N Obtiene: Nen (2, 1)
# 0.0412575131632896
# Intenta: N Obtiene: Een (2, 2)
# 0.03339105195064322
# Intenta: N Obtiene: Wen (2, 0)
# 0.24737196331008016
# Intenta: S Obtiene: Sen (2, 1)
# 0.0412575131632896
# Intenta: S Obtiene: Een (2, 2)
# 0.03339105195064322
# Intenta: S Obtiene: Wen (2, 0)
# 0.3300601053063168
# Intenta: E Obtiene: Een (2, 2)
# 0.03092149541376002
# Intenta: E Obtiene: Nen (2, 1)
# 0.03092149541376002
# Intenta: E Obtiene: Sen (2, 1)
# 0.2671284156051458
# Intenta: W Obtiene: Wen (2, 0)
# 0.03092149541376002
# Intenta: W Obtiene: Nen (2, 1)
# 0.03092149541376002
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.322020528424013, 'S': 0.322020528424013, 'E': 0.3919030961338368, 'W': 0.32897140643266576}
# 0.4108056905459037
# Intenta: N Obtiene: Nen (1, 2)
# 0.023431835878566912
# Intenta: N Obtiene: Een (2, 3)
# 0.03527127865204532
# Intenta: N Obtiene: Wen (2, 1)
# 0.3300601053063168
# Intenta: S Obtiene: Sen (2, 2)
# 0.023431835878566912
# Intenta: S Obtiene: Een (2, 3)
# 0.03527127865204532
# Intenta: S Obtiene: Wen (2, 1)
# 0.1874546870285353
# Intenta: E Obtiene: Een (2, 3)
# 0.051350711318237964
# Intenta: E Obtiene: Nen (1, 2)
# 0.0412575131632896
# Intenta: E Obtiene: Sen (2, 2)
# 0.28217022921636253
# Intenta: W Obtiene: Wen (2, 1)
# 0.051350711318237964
# Intenta: W Obtiene: Nen (1, 2)
# 0.0412575131632896
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.46950880507651593, 'S': 0.388763219836929, 'E': 0.28006291151006285, 'W': 0.3747784536978901}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.023431835878566912
# Intenta: N Obtiene: Een (2, 3)
# 0.04225579245688644
# Intenta: N Obtiene: Wen (2, 2)
# 0.1874546870285353
# Intenta: S Obtiene: Sen (2, 3)
# 0.023431835878566912
# Intenta: S Obtiene: Een (2, 3)
# 0.04225579245688644
# Intenta: S Obtiene: Wen (2, 2)
# 0.1874546870285353
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.023431835878566912
# Intenta: E Obtiene: Sen (2, 3)
# 0.3380463396550915
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.023431835878566912
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6543123716645467, 'S': 0.2531423153639886, 'E': 0.1208865229071022, 'W': 0.2714781755336584}
# 0.39728965017600015
# Intenta: N Obtiene: Nen (0, 0)
# 0.06573037434624
# Intenta: N Obtiene: Een (0, 1)
# 0.04966120627200002
# Intenta: N Obtiene: Wen (0, 0)
# 0.32087706550272016
# Intenta: S Obtiene: Sen (1, 0)
# 0.06573037434624
# Intenta: S Obtiene: Een (0, 1)
# 0.04966120627200002
# Intenta: S Obtiene: Wen (0, 0)
# 0.52584299476992
# Intenta: E Obtiene: Een (0, 1)
# 0.04966120627200002
# Intenta: E Obtiene: Nen (0, 0)
# 0.04010963318784002
# Intenta: E Obtiene: Sen (1, 0)
# 0.39728965017600015
# Intenta: W Obtiene: Wen (0, 0)
# 0.04966120627200002
# Intenta: W Obtiene: Nen (0, 0)
# 0.04010963318784002
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.5126812307942402, 'S': 0.43626864612096017, 'E': 0.61561383422976, 'W': 0.48706048963584014}
# 0.52584299476992
# Intenta: N Obtiene: Nen (0, 1)
# 0.07620790596716162
# Intenta: N Obtiene: Een (0, 2)
# 0.0554052450806784
# Intenta: N Obtiene: Wen (0, 0)
# 0.52584299476992
# Intenta: S Obtiene: Sen (0, 1)
# 0.07620790596716162
# Intenta: S Obtiene: Een (0, 2)
# 0.0554052450806784
# Intenta: S Obtiene: Wen (0, 0)
# 0.609663247737293
# Intenta: E Obtiene: Een (0, 2)
# 0.06573037434624
# Intenta: E Obtiene: Nen (0, 1)
# 0.06573037434624
# Intenta: E Obtiene: Sen (0, 1)
# 0.4432419606454272
# Intenta: W Obtiene: Wen (0, 0)
# 0.06573037434624
# Intenta: W Obtiene: Nen (0, 1)
# 0.06573037434624
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.6574561458177601, 'S': 0.6574561458177601, 'E': 0.7411239964297729, 'W': 0.5747027093379071}
# 0.609663247737293
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06670115967867957
# Intenta: N Obtiene: Wen (0, 1)
# 0.4108056905459037
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06670115967867957
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.07620790596716162
# Intenta: E Obtiene: Nen (0, 2)
# 0.051350711318237964
# Intenta: E Obtiene: Sen (1, 2)
# 0.5336092774294365
# Intenta: W Obtiene: Wen (0, 1)
# 0.07620790596716162
# Intenta: W Obtiene: Nen (0, 2)
# 0.051350711318237964
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.7663644074159726, 'S': 0.5675068502245832, 'E': 0.8475586172853997, 'W': 0.6611678947148362}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.4432419606454272
# Intenta: N Obtiene: Nen (0, 0)
# 0.04010963318784002
# Intenta: N Obtiene: Een (1, 0)
# 0.04010963318784002
# Intenta: N Obtiene: Wen (1, 0)
# 0.2671284156051458
# Intenta: S Obtiene: Sen (2, 0)
# 0.04010963318784002
# Intenta: S Obtiene: Een (1, 0)
# 0.04010963318784002
# Intenta: S Obtiene: Wen (1, 0)
# 0.32087706550272016
# Intenta: E Obtiene: Een (1, 0)
# 0.0554052450806784
# Intenta: E Obtiene: Nen (0, 0)
# 0.03339105195064322
# Intenta: E Obtiene: Sen (2, 0)
# 0.32087706550272016
# Intenta: W Obtiene: Wen (1, 0)
# 0.0554052450806784
# Intenta: W Obtiene: Nen (0, 0)
# 0.03339105195064322
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.5234612270211072, 'S': 0.3473476819808258, 'E': 0.4096733625340418, 'W': 0.4096733625340418}
# 0.6102422044454878
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.051350711318237964
# Intenta: N Obtiene: Wen (1, 2)
# 0.3380463396550915
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.051350711318237964
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07628027555568598
# Intenta: E Obtiene: Nen (0, 2)
# 0.04225579245688644
# Intenta: E Obtiene: Sen (2, 2)
# 0.4108056905459037
# Intenta: W Obtiene: Wen (1, 2)
# 0.07628027555568598
# Intenta: W Obtiene: Nen (0, 2)
# 0.04225579245688644
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.5715929157637258, 'S': 0.29939705097332947, 'E': -0.6014639319874276, 'W': 0.5293417585584762}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.3768920834551972
# Intenta: N Obtiene: Nen (1, 0)
# 0.03527127865204532
# Intenta: N Obtiene: Een (2, 1)
# 0.03339105195064322
# Intenta: N Obtiene: Wen (2, 0)
# 0.2671284156051458
# Intenta: S Obtiene: Sen (2, 0)
# 0.03527127865204532
# Intenta: S Obtiene: Een (2, 1)
# 0.03339105195064322
# Intenta: S Obtiene: Wen (2, 0)
# 0.28217022921636253
# Intenta: E Obtiene: Een (2, 1)
# 0.04711151043189965
# Intenta: E Obtiene: Nen (1, 0)
# 0.03339105195064322
# Intenta: E Obtiene: Sen (2, 0)
# 0.2671284156051458
# Intenta: W Obtiene: Wen (2, 0)
# 0.04711151043189965
# Intenta: W Obtiene: Nen (1, 0)
# 0.03339105195064322
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.44555441405788576, 'S': 0.33579074620783433, 'E': 0.3626727915989054, 'W': 0.34763097798768866}
# 0.28217022921636253
# Intenta: N Obtiene: Nen (2, 1)
# 0.04225579245688644
# Intenta: N Obtiene: Een (2, 2)
# 0.040099897265209725
# Intenta: N Obtiene: Wen (2, 0)
# 0.28217022921636253
# Intenta: S Obtiene: Sen (2, 1)
# 0.04225579245688644
# Intenta: S Obtiene: Een (2, 2)
# 0.040099897265209725
# Intenta: S Obtiene: Wen (2, 0)
# 0.3380463396550915
# Intenta: E Obtiene: Een (2, 2)
# 0.03527127865204532
# Intenta: E Obtiene: Nen (2, 1)
# 0.03527127865204532
# Intenta: E Obtiene: Sen (2, 1)
# 0.3207991781216778
# Intenta: W Obtiene: Wen (2, 0)
# 0.03527127865204532
# Intenta: W Obtiene: Nen (2, 1)
# 0.03527127865204532
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.3645259189384587, 'S': 0.3645259189384587, 'E': 0.40858889695918216, 'W': 0.39134173542576844}
# 0.41154689934988264
# Intenta: N Obtiene: Nen (1, 2)
# 0.024433035798029256
# Intenta: N Obtiene: Een (2, 3)
# 0.036773000726326395
# Intenta: N Obtiene: Wen (2, 1)
# 0.3380463396550915
# Intenta: S Obtiene: Sen (2, 2)
# 0.024433035798029256
# Intenta: S Obtiene: Een (2, 3)
# 0.036773000726326395
# Intenta: S Obtiene: Wen (2, 1)
# 0.19546428638423405
# Intenta: E Obtiene: Een (2, 3)
# 0.05144336241873533
# Intenta: E Obtiene: Nen (1, 2)
# 0.04225579245688644
# Intenta: E Obtiene: Sen (2, 2)
# 0.29418400581061116
# Intenta: W Obtiene: Wen (2, 1)
# 0.05144336241873533
# Intenta: W Obtiene: Nen (1, 2)
# 0.04225579245688644
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.4727529358742383, 'S': 0.39925237617944714, 'E': 0.2891634412598558, 'W': 0.3878831606862329}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.024433035798029256
# Intenta: N Obtiene: Een (2, 3)
# 0.04254776422868145
# Intenta: N Obtiene: Wen (2, 2)
# 0.19546428638423405
# Intenta: S Obtiene: Sen (2, 3)
# 0.024433035798029256
# Intenta: S Obtiene: Een (2, 3)
# 0.04254776422868145
# Intenta: S Obtiene: Wen (2, 2)
# 0.19546428638423405
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.024433035798029256
# Intenta: E Obtiene: Sen (2, 3)
# 0.3403821138294516
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.024433035798029256
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6530191999732894, 'S': 0.2624450864109448, 'E': 0.1298973221822633, 'W': 0.2748151496274808}
# 0.4432419606454272
# Intenta: N Obtiene: Nen (0, 0)
# 0.06670115967867957
# Intenta: N Obtiene: Een (0, 1)
# 0.0554052450806784
# Intenta: N Obtiene: Wen (0, 0)
# 0.3768920834551972
# Intenta: S Obtiene: Sen (1, 0)
# 0.06670115967867957
# Intenta: S Obtiene: Een (0, 1)
# 0.0554052450806784
# Intenta: S Obtiene: Wen (0, 0)
# 0.5336092774294365
# Intenta: E Obtiene: Een (0, 1)
# 0.0554052450806784
# Intenta: E Obtiene: Nen (0, 0)
# 0.04711151043189965
# Intenta: E Obtiene: Sen (1, 0)
# 0.4432419606454272
# Intenta: W Obtiene: Wen (0, 0)
# 0.0554052450806784
# Intenta: W Obtiene: Nen (0, 0)
# 0.04711151043189965
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.5653483654047851, 'S': 0.49899848821455517, 'E': 0.6361260329420145, 'W': 0.5457587161580053}
# 0.5336092774294365
# Intenta: N Obtiene: Nen (0, 1)
# 0.07628027555568598
# Intenta: N Obtiene: Een (0, 2)
# 0.05725134296478131
# Intenta: N Obtiene: Wen (0, 0)
# 0.5336092774294365
# Intenta: S Obtiene: Sen (0, 1)
# 0.07628027555568598
# Intenta: S Obtiene: Een (0, 2)
# 0.05725134296478131
# Intenta: S Obtiene: Wen (0, 0)
# 0.6102422044454878
# Intenta: E Obtiene: Een (0, 2)
# 0.06670115967867957
# Intenta: E Obtiene: Nen (0, 1)
# 0.06670115967867957
# Intenta: E Obtiene: Sen (0, 1)
# 0.45801074371825046
# Intenta: W Obtiene: Wen (0, 0)
# 0.06670115967867957
# Intenta: W Obtiene: Nen (0, 1)
# 0.06670115967867957
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.6671408959499038, 'S': 0.6671408959499038, 'E': 0.7436445238028468, 'W': 0.5914130630756096}
# 0.6102422044454878
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06692800714225622
# Intenta: N Obtiene: Wen (0, 1)
# 0.41154689934988264
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06692800714225622
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.07628027555568598
# Intenta: E Obtiene: Nen (0, 2)
# 0.05144336241873533
# Intenta: E Obtiene: Sen (1, 2)
# 0.5354240571380497
# Intenta: W Obtiene: Wen (0, 1)
# 0.07628027555568598
# Intenta: W Obtiene: Nen (0, 2)
# 0.05144336241873533
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.767170211587744, 'S': 0.5684749064921388, 'E': 0.8477236379744214, 'W': 0.6631476951124711}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.45801074371825046
# Intenta: N Obtiene: Nen (0, 0)
# 0.04711151043189965
# Intenta: N Obtiene: Een (1, 0)
# 0.04711151043189965
# Intenta: N Obtiene: Wen (1, 0)
# 0.3207991781216778
# Intenta: S Obtiene: Sen (2, 0)
# 0.04711151043189965
# Intenta: S Obtiene: Een (1, 0)
# 0.04711151043189965
# Intenta: S Obtiene: Wen (1, 0)
# 0.3768920834551972
# Intenta: E Obtiene: Een (1, 0)
# 0.05725134296478131
# Intenta: E Obtiene: Nen (0, 0)
# 0.040099897265209725
# Intenta: E Obtiene: Sen (2, 0)
# 0.3768920834551972
# Intenta: W Obtiene: Wen (1, 0)
# 0.05725134296478131
# Intenta: W Obtiene: Nen (0, 0)
# 0.040099897265209725
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.5522337645820498, 'S': 0.4150221989854771, 'E': 0.47424332368518823, 'W': 0.47424332368518823}
# 0.6103610193415835
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.05144336241873533
# Intenta: N Obtiene: Wen (1, 2)
# 0.3403821138294516
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.05144336241873533
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07629512741769794
# Intenta: E Obtiene: Nen (0, 2)
# 0.04254776422868145
# Intenta: E Obtiene: Sen (2, 2)
# 0.41154689934988264
# Intenta: W Obtiene: Wen (1, 2)
# 0.07629512741769794
# Intenta: W Obtiene: Nen (0, 2)
# 0.04254776422868145
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.5718043817603189, 'S': 0.3018254762481869, 'E': -0.6011571083536207, 'W': 0.530389790996262}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.39760831049907586
# Intenta: N Obtiene: Nen (1, 0)
# 0.036773000726326395
# Intenta: N Obtiene: Een (2, 1)
# 0.040099897265209725
# Intenta: N Obtiene: Wen (2, 0)
# 0.3207991781216778
# Intenta: S Obtiene: Sen (2, 0)
# 0.036773000726326395
# Intenta: S Obtiene: Een (2, 1)
# 0.040099897265209725
# Intenta: S Obtiene: Wen (2, 0)
# 0.29418400581061116
# Intenta: E Obtiene: Een (2, 1)
# 0.04970103881238448
# Intenta: E Obtiene: Nen (1, 0)
# 0.040099897265209725
# Intenta: E Obtiene: Sen (2, 0)
# 0.3207991781216778
# Intenta: W Obtiene: Wen (2, 0)
# 0.04970103881238448
# Intenta: W Obtiene: Nen (1, 0)
# 0.040099897265209725
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.474481208490612, 'S': 0.3976720761132139, 'E': 0.38398494188820537, 'W': 0.410600114199272}
# 0.29418400581061116
# Intenta: N Obtiene: Nen (2, 1)
# 0.04254776422868145
# Intenta: N Obtiene: Een (2, 2)
# 0.04270330876415508
# Intenta: N Obtiene: Wen (2, 0)
# 0.29418400581061116
# Intenta: S Obtiene: Sen (2, 1)
# 0.04254776422868145
# Intenta: S Obtiene: Een (2, 2)
# 0.04270330876415508
# Intenta: S Obtiene: Wen (2, 0)
# 0.3403821138294516
# Intenta: E Obtiene: Een (2, 2)
# 0.036773000726326395
# Intenta: E Obtiene: Nen (2, 1)
# 0.036773000726326395
# Intenta: E Obtiene: Sen (2, 1)
# 0.34162647011324065
# Intenta: W Obtiene: Wen (2, 0)
# 0.036773000726326395
# Intenta: W Obtiene: Nen (2, 1)
# 0.036773000726326395
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.3794350788034477, 'S': 0.3794350788034477, 'E': 0.4139281152821044, 'W': 0.41517247156589343}
# 0.4116991548674296
# Intenta: N Obtiene: Nen (1, 2)
# 0.024733363466473274
# Intenta: N Obtiene: Een (2, 3)
# 0.03736552244093041
# Intenta: N Obtiene: Wen (2, 1)
# 0.3403821138294516
# Intenta: S Obtiene: Sen (2, 2)
# 0.024733363466473274
# Intenta: S Obtiene: Een (2, 3)
# 0.03736552244093041
# Intenta: S Obtiene: Wen (2, 1)
# 0.1978669077317862
# Intenta: E Obtiene: Een (2, 3)
# 0.0514623943584287
# Intenta: E Obtiene: Nen (1, 2)
# 0.04254776422868145
# Intenta: E Obtiene: Sen (2, 2)
# 0.29892417952744327
# Intenta: W Obtiene: Wen (2, 1)
# 0.0514623943584287
# Intenta: W Obtiene: Nen (1, 2)
# 0.04254776422868145
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.47379804077483323, 'S': 0.40248099973685525, 'E': 0.2918770663188963, 'W': 0.3929343381145534}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.024733363466473274
# Intenta: N Obtiene: Een (2, 3)
# 0.04264182366973499
# Intenta: N Obtiene: Wen (2, 2)
# 0.1978669077317862
# Intenta: S Obtiene: Sen (2, 3)
# 0.024733363466473274
# Intenta: S Obtiene: Een (2, 3)
# 0.04264182366973499
# Intenta: S Obtiene: Wen (2, 2)
# 0.1978669077317862
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.024733363466473274
# Intenta: E Obtiene: Sen (2, 3)
# 0.34113458935787994
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.024733363466473274
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6526248128637918, 'S': 0.2652420948679945, 'E': 0.13260027119825946, 'W': 0.27586795282435317}
# 0.45801074371825046
# Intenta: N Obtiene: Nen (0, 0)
# 0.06692800714225622
# Intenta: N Obtiene: Een (0, 1)
# 0.05725134296478131
# Intenta: N Obtiene: Wen (0, 0)
# 0.39760831049907586
# Intenta: S Obtiene: Sen (1, 0)
# 0.06692800714225622
# Intenta: S Obtiene: Een (0, 1)
# 0.05725134296478131
# Intenta: S Obtiene: Wen (0, 0)
# 0.5354240571380497
# Intenta: E Obtiene: Een (0, 1)
# 0.05725134296478131
# Intenta: E Obtiene: Nen (0, 0)
# 0.04970103881238448
# Intenta: E Obtiene: Sen (1, 0)
# 0.45801074371825046
# Intenta: W Obtiene: Wen (0, 0)
# 0.05725134296478131
# Intenta: W Obtiene: Nen (0, 0)
# 0.04970103881238448
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.582190093825288, 'S': 0.5217876606061134, 'E': 0.6423764389152156, 'W': 0.5649631254954163}
# 0.5354240571380497
# Intenta: N Obtiene: Nen (0, 1)
# 0.07629512741769794
# Intenta: N Obtiene: Een (0, 2)
# 0.05781387950236941
# Intenta: N Obtiene: Wen (0, 0)
# 0.5354240571380497
# Intenta: S Obtiene: Sen (0, 1)
# 0.07629512741769794
# Intenta: S Obtiene: Een (0, 2)
# 0.05781387950236941
# Intenta: S Obtiene: Wen (0, 0)
# 0.6103610193415835
# Intenta: E Obtiene: Een (0, 2)
# 0.06692800714225622
# Intenta: E Obtiene: Nen (0, 1)
# 0.06692800714225622
# Intenta: E Obtiene: Sen (0, 1)
# 0.46251103601895527
# Intenta: W Obtiene: Wen (0, 0)
# 0.06692800714225622
# Intenta: W Obtiene: Nen (0, 1)
# 0.06692800714225622
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.6695330640581171, 'S': 0.6695330640581171, 'E': 0.7442170336260959, 'W': 0.5963670503034677}
# 0.6103610193415835
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06697953302634864
# Intenta: N Obtiene: Wen (0, 1)
# 0.4116991548674296
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06697953302634864
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.07629512741769794
# Intenta: E Obtiene: Nen (0, 2)
# 0.0514623943584287
# Intenta: E Obtiene: Sen (1, 2)
# 0.5358362642107891
# Intenta: W Obtiene: Wen (0, 1)
# 0.07629512741769794
# Intenta: W Obtiene: Nen (0, 2)
# 0.0514623943584287
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.7673405523679321, 'S': 0.5686786878937782, 'E': 0.8477575217761267, 'W': 0.6635937859869158}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.46251103601895527
# Intenta: N Obtiene: Nen (0, 0)
# 0.04970103881238448
# Intenta: N Obtiene: Een (1, 0)
# 0.04970103881238448
# Intenta: N Obtiene: Wen (1, 0)
# 0.34162647011324065
# Intenta: S Obtiene: Sen (2, 0)
# 0.04970103881238448
# Intenta: S Obtiene: Een (1, 0)
# 0.04970103881238448
# Intenta: S Obtiene: Wen (1, 0)
# 0.39760831049907586
# Intenta: E Obtiene: Een (1, 0)
# 0.05781387950236941
# Intenta: E Obtiene: Nen (0, 0)
# 0.04270330876415508
# Intenta: E Obtiene: Sen (2, 0)
# 0.39760831049907586
# Intenta: W Obtiene: Wen (1, 0)
# 0.05781387950236941
# Intenta: W Obtiene: Nen (0, 0)
# 0.04270330876415508
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.5619131136437243, 'S': 0.4410285477380096, 'E': 0.4981254987656003, 'W': 0.4981254987656003}
# 0.6103854156788113
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.0514623943584287
# Intenta: N Obtiene: Wen (1, 2)
# 0.34113458935787994
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.0514623943584287
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07629817695985142
# Intenta: E Obtiene: Nen (0, 2)
# 0.04264182366973499
# Intenta: E Obtiene: Sen (2, 2)
# 0.4116991548674296
# Intenta: W Obtiene: Wen (1, 2)
# 0.07629817695985142
# Intenta: W Obtiene: Nen (0, 2)
# 0.04264182366973499
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.5718478100372401, 'S': 0.3025969837163086, 'E': -0.6010599993704137, 'W': 0.530639155497016}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.40457744182348154
# Intenta: N Obtiene: Nen (1, 0)
# 0.03736552244093041
# Intenta: N Obtiene: Een (2, 1)
# 0.04270330876415508
# Intenta: N Obtiene: Wen (2, 0)
# 0.34162647011324065
# Intenta: S Obtiene: Sen (2, 0)
# 0.03736552244093041
# Intenta: S Obtiene: Een (2, 1)
# 0.04270330876415508
# Intenta: S Obtiene: Wen (2, 0)
# 0.29892417952744327
# Intenta: E Obtiene: Een (2, 1)
# 0.05057218022793519
# Intenta: E Obtiene: Nen (1, 0)
# 0.04270330876415508
# Intenta: E Obtiene: Sen (2, 0)
# 0.34162647011324065
# Intenta: W Obtiene: Wen (2, 0)
# 0.05057218022793519
# Intenta: W Obtiene: Nen (1, 0)
# 0.04270330876415508
# ...
# 0.02495535199375001
# Intenta: N Obtiene: Een (2, 3)
# 0.04279196792158392
# Intenta: N Obtiene: Wen (2, 2)
# 0.19964281595000008
# Intenta: S Obtiene: Sen (2, 3)
# 0.02495535199375001
# Intenta: S Obtiene: Een (2, 3)
# 0.04279196792158392
# Intenta: S Obtiene: Wen (2, 2)
# 0.19964281595000008
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.02495535199375001
# Intenta: E Obtiene: Sen (2, 3)
# 0.34233574337267136
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.02495535199375001
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6522526800846662, 'S': 0.267390135865334, 'E': 0.13459816794375007, 'W': 0.2772910953664213}
# 0.4643744635909497
# Intenta: N Obtiene: Nen (0, 0)
# 0.06699420647064762
# Intenta: N Obtiene: Een (0, 1)
# 0.05804680794886871
# Intenta: N Obtiene: Wen (0, 0)
# 0.4077397395539133
# Intenta: S Obtiene: Sen (1, 0)
# 0.06699420647064762
# Intenta: S Obtiene: Een (0, 1)
# 0.05804680794886871
# Intenta: S Obtiene: Wen (0, 0)
# 0.535953651765181
# Intenta: E Obtiene: Een (0, 1)
# 0.05804680794886871
# Intenta: E Obtiene: Nen (0, 0)
# 0.05096746744423916
# Intenta: E Obtiene: Sen (1, 0)
# 0.4643744635909497
# Intenta: W Obtiene: Wen (0, 0)
# 0.05804680794886871
# Intenta: W Obtiene: Nen (0, 0)
# 0.05096746744423916
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.589415478010466, 'S': 0.5327807539734296, 'E': 0.6449679271582889, 'W': 0.5733887389840576}
# 0.535953651765181
# Intenta: N Obtiene: Nen (0, 1)
# 0.07629896473250153
# Intenta: N Obtiene: Een (0, 2)
# 0.058047113444246005
# Intenta: N Obtiene: Wen (0, 0)
# 0.535953651765181
# Intenta: S Obtiene: Sen (0, 1)
# 0.07629896473250153
# Intenta: S Obtiene: Een (0, 2)
# 0.058047113444246005
# Intenta: S Obtiene: Wen (0, 0)
# 0.6103917178600122
# Intenta: E Obtiene: Een (0, 2)
# 0.06699420647064762
# Intenta: E Obtiene: Nen (0, 1)
# 0.06699420647064762
# Intenta: E Obtiene: Sen (0, 1)
# 0.46437690755396804
# Intenta: W Obtiene: Wen (0, 0)
# 0.06699420647064762
# Intenta: W Obtiene: Nen (0, 1)
# 0.06699420647064762
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.6702997299419284, 'S': 0.6702997299419284, 'E': 0.7443801308013074, 'W': 0.5983653204952633}
# 0.6103917178600122
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06699421177211766
# Intenta: N Obtiene: Wen (0, 1)
# 0.4117385009136736
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06699421177211766
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.07629896473250153
# Intenta: E Obtiene: Nen (0, 2)
# 0.0514673126142092
# Intenta: E Obtiene: Sen (1, 2)
# 0.5359536941769413
# Intenta: W Obtiene: Wen (0, 1)
# 0.07629896473250153
# Intenta: W Obtiene: Nen (0, 2)
# 0.0514673126142092
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.7673859296321298, 'S': 0.5687327126857912, 'E': 0.8477662773467108, 'W': 0.663719971523652}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.46437690755396804
# Intenta: N Obtiene: Nen (0, 0)
# 0.05096746744423916
# Intenta: N Obtiene: Een (1, 0)
# 0.05096746744423916
# Intenta: N Obtiene: Wen (1, 0)
# 0.3532748048037802
# Intenta: S Obtiene: Sen (2, 0)
# 0.05096746744423916
# Intenta: S Obtiene: Een (1, 0)
# 0.05096746744423916
# Intenta: S Obtiene: Wen (1, 0)
# 0.4077397395539133
# Intenta: E Obtiene: Een (1, 0)
# 0.058047113444246005
# Intenta: E Obtiene: Nen (0, 0)
# 0.044159350600472526
# Intenta: E Obtiene: Sen (2, 0)
# 0.4077397395539133
# Intenta: W Obtiene: Wen (1, 0)
# 0.058047113444246005
# Intenta: W Obtiene: Nen (0, 0)
# 0.044159350600472526
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.5663118424424464, 'S': 0.45520973969225853, 'E': 0.5099462035986319, 'W': 0.5099462035986319}
# 0.6103917196896318
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.0514673126142092
# Intenta: N Obtiene: Wen (1, 2)
# 0.34233574337267136
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.0514673126142092
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07629896496120397
# Intenta: E Obtiene: Nen (0, 2)
# 0.04279196792158392
# Intenta: E Obtiene: Sen (2, 2)
# 0.4117385009136736
# Intenta: W Obtiene: Wen (1, 2)
# 0.07629896496120397
# Intenta: W Obtiene: Nen (0, 2)
# 0.04279196792158392
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.571859032303841, 'S': 0.3038030559868805, 'E': -0.6009090671172123, 'W': 0.5308294337964615}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.4077445265585614
# Intenta: N Obtiene: Nen (1, 0)
# 0.03877245733239772
# Intenta: N Obtiene: Een (2, 1)
# 0.044159350600472526
# Intenta: N Obtiene: Wen (2, 0)
# 0.3532748048037802
# Intenta: S Obtiene: Sen (2, 0)
# 0.03877245733239772
# Intenta: S Obtiene: Een (2, 1)
# 0.044159350600472526
# Intenta: S Obtiene: Wen (2, 0)
# 0.31017965865918173
# Intenta: E Obtiene: Een (2, 1)
# 0.05096806581982018
# Intenta: E Obtiene: Nen (1, 0)
# 0.044159350600472526
# Intenta: E Obtiene: Sen (2, 0)
# 0.3532748048037802
# Intenta: W Obtiene: Wen (2, 0)
# 0.05096806581982018
# Intenta: W Obtiene: Nen (1, 0)
# 0.044159350600472526
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.49067633449143166, 'S': 0.43620661273665046, 'E': 0.40530707507947444, 'W': 0.4484022212240729}
# 0.31017965865918173
# Intenta: N Obtiene: Nen (2, 1)
# 0.04279196792158392
# Intenta: N Obtiene: Een (2, 2)
# 0.04416087010422885
# Intenta: N Obtiene: Wen (2, 0)
# 0.31017965865918173
# Intenta: S Obtiene: Sen (2, 1)
# 0.04279196792158392
# Intenta: S Obtiene: Een (2, 2)
# 0.04416087010422885
# Intenta: S Obtiene: Wen (2, 0)
# 0.34233574337267136
# Intenta: E Obtiene: Een (2, 2)
# 0.03877245733239772
# Intenta: E Obtiene: Nen (2, 1)
# 0.03877245733239772
# Intenta: E Obtiene: Sen (2, 1)
# 0.3532869608338308
# Intenta: W Obtiene: Wen (2, 0)
# 0.03877245733239772
# Intenta: W Obtiene: Nen (2, 1)
# 0.03877245733239772
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.3971324966849945, 'S': 0.3971324966849945, 'E': 0.41988065803746677, 'W': 0.4308318754986262}
# 0.4117385032587656
# Intenta: N Obtiene: Nen (1, 2)
# 0.024956198582977922
# Intenta: N Obtiene: Een (2, 3)
# 0.03877486879487636
# Intenta: N Obtiene: Wen (2, 1)
# 0.34233574337267136
# Intenta: S Obtiene: Sen (2, 2)
# 0.024956198582977922
# Intenta: S Obtiene: Een (2, 3)
# 0.03877486879487636
# Intenta: S Obtiene: Wen (2, 1)
# 0.19964958866382337
# Intenta: E Obtiene: Een (2, 3)
# 0.0514673129073457
# Intenta: E Obtiene: Nen (1, 2)
# 0.04279196792158392
# Intenta: E Obtiene: Sen (2, 2)
# 0.3101989503590109
# Intenta: W Obtiene: Wen (2, 1)
# 0.0514673129073457
# Intenta: W Obtiene: Nen (1, 2)
# 0.04279196792158392
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.4754695706366199, 'S': 0.40606681075052564, 'E': 0.29390886949275297, 'W': 0.4044582311879405}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.024956198582977922
# Intenta: N Obtiene: Een (2, 3)
# 0.042792261357295795
# Intenta: N Obtiene: Wen (2, 2)
# 0.19964958866382337
# Intenta: S Obtiene: Sen (2, 3)
# 0.024956198582977922
# Intenta: S Obtiene: Een (2, 3)
# 0.042792261357295795
# Intenta: S Obtiene: Wen (2, 2)
# 0.19964958866382337
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.024956198582977922
# Intenta: E Obtiene: Sen (2, 3)
# 0.34233809085836636
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.024956198582977922
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6522515400597264, 'S': 0.2673980486040971, 'E': 0.13460578724680128, 'W': 0.27729428944134427}
# 0.46437690755396804
# Intenta: N Obtiene: Nen (0, 0)
# 0.06699421177211766
# Intenta: N Obtiene: Een (0, 1)
# 0.058047113444246005
# Intenta: N Obtiene: Wen (0, 0)
# 0.4077445265585614
# Intenta: S Obtiene: Sen (1, 0)
# 0.06699421177211766
# Intenta: S Obtiene: Een (0, 1)
# 0.058047113444246005
# Intenta: S Obtiene: Wen (0, 0)
# 0.5359536941769413
# Intenta: E Obtiene: Een (0, 1)
# 0.058047113444246005
# Intenta: E Obtiene: Nen (0, 0)
# 0.05096806581982018
# Intenta: E Obtiene: Sen (1, 0)
# 0.46437690755396804
# Intenta: W Obtiene: Wen (0, 0)
# 0.058047113444246005
# Intenta: W Obtiene: Nen (0, 0)
# 0.05096806581982018
# Intenta: W Obtiene: Sen (1, 0)
# (0, 0)
# {'N': 0.5894182327703317, 'S': 0.5327858517749251, 'E': 0.6449688734410074, 'W': 0.5733920868180342}
# 0.5359536941769413
# Intenta: N Obtiene: Nen (0, 1)
# 0.07629896496120397
# Intenta: N Obtiene: Een (0, 2)
# 0.05804719860969067
# Intenta: N Obtiene: Wen (0, 0)
# 0.5359536941769413
# Intenta: S Obtiene: Sen (0, 1)
# 0.07629896496120397
# Intenta: S Obtiene: Een (0, 2)
# 0.05804719860969067
# Intenta: S Obtiene: Wen (0, 0)
# 0.6103917196896318
# Intenta: E Obtiene: Een (0, 2)
# 0.06699421177211766
# Intenta: E Obtiene: Nen (0, 1)
# 0.06699421177211766
# Intenta: E Obtiene: Sen (0, 1)
# 0.46437758887752534
# Intenta: W Obtiene: Wen (0, 0)
# 0.06699421177211766
# Intenta: W Obtiene: Nen (0, 1)
# 0.06699421177211766
# Intenta: W Obtiene: Sen (0, 1)
# (0, 1)
# {'N': 0.6702998577478358, 'S': 0.6702998577478358, 'E': 0.744380143233867, 'W': 0.5983660124217606}
# 0.6103917196896318
# Intenta: N Obtiene: Nen (0, 2)
# 0.09000000000000001
# Intenta: N Obtiene: Een (0, 3)
# 0.06699421289104804
# Intenta: N Obtiene: Wen (0, 1)
# 0.4117385032587656
# Intenta: S Obtiene: Sen (1, 2)
# 0.09000000000000001
# Intenta: S Obtiene: Een (0, 3)
# 0.06699421289104804
# Intenta: S Obtiene: Wen (0, 1)
# 0.7200000000000001
# Intenta: E Obtiene: Een (0, 3)
# 0.07629896496120397
# Intenta: E Obtiene: Nen (0, 2)
# 0.0514673129073457
# Intenta: E Obtiene: Sen (1, 2)
# 0.5359537031283843
# Intenta: W Obtiene: Wen (0, 1)
# 0.07629896496120397
# Intenta: W Obtiene: Nen (0, 2)
# 0.0514673129073457
# Intenta: W Obtiene: Sen (1, 2)
# (0, 2)
# {'N': 0.7673859325806798, 'S': 0.5687327161498136, 'E': 0.8477662778685497, 'W': 0.6637199809969341}
# 0.8
# Intenta: N Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: N Obtiene: Een Terminal Diamante
# 0.1
# Intenta: N Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: S Obtiene: Sen Terminal Diamante
# 0.1
# Intenta: S Obtiene: Een Terminal Diamante
# 0.1
# Intenta: S Obtiene: Wen Terminal Diamante
# 0.8
# Intenta: E Obtiene: Een Terminal Diamante
# 0.1
# Intenta: E Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: E Obtiene: Sen Terminal Diamante
# 0.8
# Intenta: W Obtiene: Wen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Nen Terminal Diamante
# 0.1
# Intenta: W Obtiene: Sen Terminal Diamante
# (0, 3)
# {'N': 1.0, 'S': 1.0, 'E': 1.0, 'W': 1.0}
# 0.46437758887752534
# Intenta: N Obtiene: Nen (0, 0)
# 0.05096806581982018
# Intenta: N Obtiene: Een (1, 0)
# 0.05096806581982018
# Intenta: N Obtiene: Wen (1, 0)
# 0.3532869608338308
# Intenta: S Obtiene: Sen (2, 0)
# 0.05096806581982018
# Intenta: S Obtiene: Een (1, 0)
# 0.05096806581982018
# Intenta: S Obtiene: Wen (1, 0)
# 0.4077445265585614
# Intenta: E Obtiene: Een (1, 0)
# 0.05804719860969067
# Intenta: E Obtiene: Nen (0, 0)
# 0.04416087010422885
# Intenta: E Obtiene: Sen (2, 0)
# 0.4077445265585614
# Intenta: W Obtiene: Wen (1, 0)
# 0.05804719860969067
# Intenta: W Obtiene: Nen (0, 0)
# 0.04416087010422885
# Intenta: W Obtiene: Sen (2, 0)
# (1, 0)
# {'N': 0.5663137205171657, 'S': 0.45522309247347115, 'E': 0.5099525952724809, 'W': 0.5099525952724809}
# 0.6103917200653559
# Intenta: N Obtiene: Nen (0, 2)
# -0.09000000000000001
# Intenta: N Obtiene: Een (1, 3)
# 0.0514673129073457
# Intenta: N Obtiene: Wen (1, 2)
# 0.34233809085836636
# Intenta: S Obtiene: Sen (2, 2)
# -0.09000000000000001
# Intenta: S Obtiene: Een (1, 3)
# 0.0514673129073457
# Intenta: S Obtiene: Wen (1, 2)
# -0.7200000000000001
# Intenta: E Obtiene: Een (1, 3)
# 0.07629896500816949
# Intenta: E Obtiene: Nen (0, 2)
# 0.042792261357295795
# Intenta: E Obtiene: Sen (2, 2)
# 0.4117385032587656
# Intenta: W Obtiene: Wen (1, 2)
# 0.07629896500816949
# Intenta: W Obtiene: Nen (0, 2)
# 0.042792261357295795
# Intenta: W Obtiene: Sen (2, 2)
# (1, 2)
# {'N': 0.5718590329727017, 'S': 0.303805403765712, 'E': -0.6009087736345349, 'W': 0.5308297296242308}
# -0.8
# Intenta: N Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: N Obtiene: Een Terminal Bomba
# -0.1
# Intenta: N Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: S Obtiene: Sen Terminal Bomba
# -0.1
# Intenta: S Obtiene: Een Terminal Bomba
# -0.1
# Intenta: S Obtiene: Wen Terminal Bomba
# -0.8
# Intenta: E Obtiene: Een Terminal Bomba
# -0.1
# Intenta: E Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: E Obtiene: Sen Terminal Bomba
# -0.8
# Intenta: W Obtiene: Wen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Nen Terminal Bomba
# -0.1
# Intenta: W Obtiene: Sen Terminal Bomba
# (1, 3)
# {'N': -1.0, 'S': -1.0, 'E': -1.0, 'W': -1.0}
# 0.40774587877235935
# Intenta: N Obtiene: Nen (1, 0)
# 0.03877486879487636
# Intenta: N Obtiene: Een (2, 1)
# 0.04416087010422885
# Intenta: N Obtiene: Wen (2, 0)
# 0.3532869608338308
# Intenta: S Obtiene: Sen (2, 0)
# 0.03877486879487636
# Intenta: S Obtiene: Een (2, 1)
# 0.04416087010422885
# Intenta: S Obtiene: Wen (2, 0)
# 0.3101989503590109
# Intenta: E Obtiene: Een (2, 1)
# 0.05096823484654492
# Intenta: E Obtiene: Nen (1, 0)
# 0.04416087010422885
# Intenta: E Obtiene: Sen (2, 0)
# 0.3532869608338308
# Intenta: W Obtiene: Wen (2, 0)
# 0.05096823484654492
# Intenta: W Obtiene: Nen (1, 0)
# 0.04416087010422885
# Intenta: W Obtiene: Sen (2, 0)
# (2, 0)
# {'N': 0.49068161767146456, 'S': 0.43622269973293604, 'E': 0.40532805530978466, 'W': 0.4484160657846046}
# 0.3101989503590109
# Intenta: N Obtiene: Nen (2, 1)
# 0.042792261357295795
# Intenta: N Obtiene: Een (2, 2)
# 0.04416134559043181
# Intenta: N Obtiene: Wen (2, 0)
# 0.3101989503590109
# Intenta: S Obtiene: Sen (2, 1)
# 0.042792261357295795
# Intenta: S Obtiene: Een (2, 2)
# 0.04416134559043181
# Intenta: S Obtiene: Wen (2, 0)
# 0.34233809085836636
# Intenta: E Obtiene: Een (2, 2)
# 0.03877486879487636
# Intenta: E Obtiene: Nen (2, 1)
# 0.03877486879487636
# Intenta: E Obtiene: Sen (2, 1)
# 0.3532907647234545
# Intenta: W Obtiene: Wen (2, 0)
# 0.03877486879487636
# Intenta: W Obtiene: Nen (2, 1)
# 0.03877486879487636
# Intenta: W Obtiene: Sen (2, 1)
# (2, 1)
# {'N': 0.39715255730673854, 'S': 0.39715255730673854, 'E': 0.41988782844811906, 'W': 0.4308405023132072}
# 0.41173850374034526
# Intenta: N Obtiene: Nen (1, 2)
# 0.024956486049720988
# Intenta: N Obtiene: Een (2, 3)
# 0.03877564520818865
# Intenta: N Obtiene: Wen (2, 1)
# 0.34233809085836636
# Intenta: S Obtiene: Sen (2, 2)
# 0.024956486049720988
# Intenta: S Obtiene: Een (2, 3)
# 0.03877564520818865
# Intenta: S Obtiene: Wen (2, 1)
# 0.1996518883977679
# Intenta: E Obtiene: Een (2, 3)
# 0.05146731296754316
# Intenta: E Obtiene: Nen (1, 2)
# 0.042792261357295795
# Intenta: E Obtiene: Sen (2, 2)
# 0.3102051616655092
# Intenta: W Obtiene: Wen (2, 1)
# 0.05146731296754316
# Intenta: W Obtiene: Nen (1, 2)
# 0.042792261357295795
# Intenta: W Obtiene: Sen (2, 2)
# (2, 2)
# {'N': 0.4754706349982549, 'S': 0.406070222116276, 'E': 0.2939114627226069, 'W': 0.40446473599034816}
# -0.7200000000000001
# Intenta: N Obtiene: Nen (1, 3)
# 0.024956486049720988
# Intenta: N Obtiene: Een (2, 3)
# 0.04279235714984295
# Intenta: N Obtiene: Wen (2, 2)
# 0.1996518883977679
# Intenta: S Obtiene: Sen (2, 3)
# 0.024956486049720988
# Intenta: S Obtiene: Een (2, 3)
# 0.04279235714984295
# Intenta: S Obtiene: Wen (2, 2)
# 0.1996518883977679
# Intenta: E Obtiene: Een (2, 3)
# -0.09000000000000001
# Intenta: E Obtiene: Nen (1, 3)
# 0.024956486049720988
# Intenta: E Obtiene: Sen (2, 3)
# 0.3423388571987436
# Intenta: W Obtiene: Wen (2, 2)
# -0.09000000000000001
# Intenta: W Obtiene: Nen (1, 3)
# 0.024956486049720988
# Intenta: W Obtiene: Sen (2, 3)
# (2, 3)
# {'N': -0.6522511568004361, 'S': 0.2674007315973318, 'E': 0.13460837444748888, 'W': 0.27729534324846455}

# %% [markdown]
# Para un horizonte de 15, los valores de los estados son:

# %%
# EDITABLE
for i in gw.state_values:
    print(gw.state_values[i])
# Out:
# 0.4219636006003152
# 0.5480838323353293
# 0.7612275449101797
# 1.0
# 0.30381379243222695
# 0.4580838323353295
# -1.0
# 0.2426975381806044
# 0.2661289736689722
# 0.36962357454185224
# 0.17612897367013364

# %% [markdown]
# **Resultado esperado:**
# ```
# V(0, 0) = 0.645
# V(0, 1) = 0.744
# V(0, 2) = 0.848
# V(0, 3) = 1.000
# V(1, 0) = 0.566
# V(1, 2) = 0.572
# V(1, 3) = -1.000
# V(2, 0) = 0.491
# V(2, 1) = 0.431
# V(2, 2) = 0.475
# V(2, 3) = 0.277
# ```

# %% [markdown]
# La política aprendida es para maximizar la recompensa desde el estado inicial (2,0) es:

# %%
# EDITABLE
for i in gw.state_values:
    print(gw.policy[i])
# Out:
# E
# E
# E
# N
# N
# N
# N
# N
# E
# N
# W

# %% [markdown]
# **Resultado esperado:**
# ```
# Acción a tomar en (0, 0): E
# Acción a tomar en (0, 1): E
# Acción a tomar en (0, 2): E
# Acción a tomar en (0, 3): N
# Acción a tomar en (1, 0): N
# Acción a tomar en (1, 2): N
# Acción a tomar en (1, 3): N
# Acción a tomar en (2, 0): N
# Acción a tomar en (2, 1): W
# Acción a tomar en (2, 2): N
# Acción a tomar en (2, 3): W
# ```

# %% [markdown]
# ## Policy Iteration
#
# Es otro método que busca aproximar los valores óptimos de cada estado basados en la política actual $\pi(s)$. La politica puede mejorarse con el tiempo, de acuerdo a los valores Q de cada par estado-acción.
#
# ### Valores Q
# $Q^{*}(s,a)$ es el valor esperado de la utilidad, si el agente comenzara en el estado $s$, tomando la acción $a$ y comportandose óptimamente en adelante.
#
# Los valores Q pueden aproximarse así:
# $$Q_{k+1}^{*}(s,a)\leftarrow \sum_{s'} P(s'|s,a)(R(s,a,s')+\gamma \max_{a'}Q_{k}^{*}(s',a'))$$

# %%
from types import MethodType
from gridworld import GridWorld, pygame
import copy
from colorama import Fore

gw = GridWorld(3, 4, [(1,1)], [(1,3)], [(0,3)], 0.0)

# %% [markdown]
# Se inicializan los valores de los estados en 0.0, al igual que los valores Q para todo par estado acción. Además, inicializamos una política que por defecto siempre toma el norte.

# %%
# Inicializar valores y política
import random
gw.state_values = gw.init_values()
gw.state_q_values = gw.init_qvalues()
gw.policy = dict.fromkeys(gw.states, 'N') 
gw.updateGrid()

# %% [markdown]
# Verifique la cantidad de valores q:

# %%
# EDITABLE
len(gw.state_q_values)
# Out:
# 11

# %% [markdown]
# **Resultado esperado:**
#
# ```
# num_q_values = 44
# ```

# %% [markdown]
# ### Algoritmo
#
# > Inicializar $\pi_{0}(s)$ de forma arbitraria<br>
# > Inicializar $V_{0}(s)$ y $Q_{0}(s,a)$ en 0.0 para todos los estados y acciones<br>
# > policy_stable = False<br>
# > Mientras(not policy_stable):<br>
# >> 1. Evaluar la política<br>
# >> Para $k=1,\cdots,H$:<br>
# >>> Para todos los estados $s$:<br>
# >>>> Para todas las acciones $s$ permitidas en $s$:<br>
# >>>>> $$Q_{k}(s,a)=\sum_{s'} P(s'|s,\pi(s))(R(s,a,s')+\gamma Q_{k-1}(s',\pi(s')))$$<br>
# >>>> Valor del estado $s$ corresponde al valor Q de la acción a ejecutar según la política $\pi_k(s)$ <br>
# >>>> $V_{k}(s)=Q_{k}(s,\pi_{k}(s))$ <br>
# >
# >> 2. Mejorar la política <br>
# >> policy_stable = True <br>
# >> Para todos los estados $s$:<br>
# >>> best_action = $arg\max_{a}Q_k(s,)$<br>
# >>> si *best_action* es diferente a lo que dice $\pi_{k}(s)$:<br>
# >>>> $\pi_{k}(s) = best\_action$<br>
# >>>> policy_stable = False<br>

# %% [markdown]
# Implemente la función de *policy evaluation* en donde se actualizan los valores $Q(s,a)$ y $V(s)$ de acuerdo a la política:
#
# Las siguientes funciones pueden ser útiles:
#
# * `gw.get_allowed_actions(state)`: Permite conocer el espacio de acciones.
# * `gw.real_actions[action]`: Las posibles acciones (reales) que puede tomar el agente.
# * `gw.action_probabilities[action]`: La probabilidad de que el agente tomé las acciones reales.
# * `gw.step(state, action, random)`: Permite ejecutar un paso en el gridworld. Con este método se puede conocer el estado siguiente, la recompensa, la accion tomada y la bandera de un estado terminal. Nota: si el parámetro random es Falso, las acciones son determinisiticas (con probabilidad 1, toma la acción dada).
# * `gw.state_values[state]`: Los valores del estado *state*.
# * `gw.policy[state]`: La acción dada por la política para el estado *state*.

# %%
# EDITABLE
def policy_evaluation(gw, gamma):        
    g_tmp = {}
    for state in gw.states:
        
        # TO DO: Actualice los valores de los estados con Policy Evaluation
        
        
            
        gw.state_values[state] =  gw.max_val(gw.state_q_values[state])

# %% [markdown]
# Ahora implemente la función *policy improvement* que permitirá ajustar la política $\pi(s)$ de acuerdo a la nueva estimación de los valores $Q(s,a)$

# %%
#EDITABLE
def policy_improvement(gw):
    # Bandera de que la política es estable
    policy_stable = True
    for state in gw.states:
        
        # TO DO: Actualice la política
        
        
        
    return policy_stable

# %% [markdown]
# Ahora resuelva el gridworld por *policy iteration* utilizando las funciones que usted implementó:
# * Incialice los estados iniciales
# * Establezca un $\gamma=0.99$, un horizonte de 15 iteraciones y el estado inicial en (2,0)

# %%
# EDITABLE

# %% [markdown]
# **Visualización:**
# 1. Ejecute la siguiente celda y haga clic sobre la ventana del gridworld.
# 2. Podrá ir viendo como se actualizan los valores de cada estado cada vez que presionas la tecla **Espacio**.
# 3. Tambien puede presionar la tecla Q en la ventana del gridworld para ver los valores Q de cada par (s,a)
# 4. Si tiene un error en la función 'policy_evaluation' o en 'policy_improvement', despues de corregirlo es necesario volver a correr las 5 celdas anteriores para poder volver a lanzar la interfaz del gridworld.
# 5. Una vez completadas las iteraciones, aparecerá un mensaje que dice TESTING. Presiona la tecla **Enter** para ver la política
# 6. Para cerrar el gridworld presiona la tecla **Esc**.

# %%
gw.policy_evaluation = MethodType(policy_evaluation, gw)
gw.policy_improvement = MethodType(policy_improvement, gw)
gw.solve_policy_iteration(gamma=gamma, horizon=H, init_state=init_state)

# %% [markdown]
# Con *policy iteration*, los valores de los estados son:

# %%
# EDITABLE

# %% [markdown]
# **Resultado esperado:**
# ```
# V(0, 0) = 0.951
# V(0, 1) = 0.964
# V(0, 2) = 0.977
# V(0, 3) = 1.000
# V(1, 0) = 0.939
# V(1, 2) = 0.890
# V(1, 3) = -1.000
# V(2, 0) = 0.925
# V(2, 1) = 0.913
# V(2, 2) = 0.900
# V(2, 3) = 0.790
# ```

# %% [markdown]
# La política aprendida es para maximizar la recompensa desde el estado inicial (2,0) es:

# %%
# EDITABLE

# %% [markdown]
# **Resultado esperado:**
# ```
# Acción a tomar en (0, 0): E
# Acción a tomar en (0, 1): E
# Acción a tomar en (0, 2): E
# Acción a tomar en (0, 3): N
# Acción a tomar en (1, 0): N
# Acción a tomar en (1, 2): W
# Acción a tomar en (1, 3): N
# Acción a tomar en (2, 0): N
# Acción a tomar en (2, 1): W
# Acción a tomar en (2, 2): W
# Acción a tomar en (2, 3): S
# ```

# %% [markdown]
# Con esto termina la implementación de los algoritmos de Policy y Value iteration, puede vovlerlos a ejecutar como desee y variar sus parámetros para ver los efectos que estos tienen.
